# %% [markdown]
# # TikTok Crawler

# %% [markdown]
# based on https://github.com/AndersGiovanni/tiktok-research-client
#
# original scripts are here: C:\Users\b1084631\Anaconda3\envs\tiktok\Lib\site-packages\tiktok_research_client

# %%
import pandas as pd

# %%
import datetime
import logging
import os
from typing import Any
from typing import Dict
from typing import List
from typing import Union

import requests
from dotenv import load_dotenv
from requests.models import Response
from tenacity import before_log
from tenacity import retry
from tenacity import stop_after_attempt
from tenacity import wait_fixed

from tiktok_research_client.utils import generate_date_ranges


# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

load_dotenv()


class TiktokClient:
    """TikTok API client."""

    def __init__(self) -> None:
        """Initialize TikTok API client."""
        self.access_token: Union[str, None] = None
        self.path_credentials = 'tiktok_credentials_sebastian_schmidt.txt'

    def read_credentials(self):
        credentials = {}
        with open(self.path_credentials, 'r') as file:
            for line in file:
                key, value = line.strip().split(': ')
                credentials[key] = value
        
        # Accessing the credentials
        self.CLIENT_KEY = credentials['CLIENT_KEY']
        self.CLIENT_SECRET = credentials['CLIENT_SECRET']
        self.GRANT_TYPE = credentials['GRANT_TYPE']

    def _get_headers(self) -> Dict[str, str]:
        """Get headers for TikTok API."""
        access_token: Dict[str, str] = self.get_access_token()

        return {
            "Content-Type": "application/json",
            "Authorization": f"Bearer {access_token['access_token']}",
        }

    def get_access_token(self) -> Dict[str, str]:
        """Get access token from TikTok API.

        The access token is valid for 7200 seconds.

        Returns:
            Dict[str, str]: Access token and its expiration time.
        """
        
        self.read_credentials()

        headers = {
            "Content-Type": "application/x-www-form-urlencoded",
            "Cache-Control": "no-cache",
        }

        payload = {
            "client_key": self.CLIENT_KEY,
            "client_secret": self.CLIENT_SECRET,
            "grant_type": self.GRANT_TYPE,
        }

        response: Response = requests.post(
            "https://open.tiktokapis.com/v2/oauth/token/",
            headers=headers,
            data=payload,
            timeout=30,
        )


        # Check if the response is successful
        response.raise_for_status()

        return response.json()  # type: ignore

    def query(self, query: Dict[Any, Any], url: str) -> Union[Dict[str, Any], None]:
        """Query TikTok API.

        Args:
            query (Dict[Any, Any]): Custom query. Follow the documentation from https://developers.tiktok.com/doc/research-api-specs-query-videos/ # noqa
            url (str): TikTok API url.

        Returns:
            Response: Response from TikTok API.
        """

        return self.fetch_data(url, query)

    def search(
        self, keywords: List[str], start_date: str, max_size: int
    ) -> List[Dict[str, str]]:
        """Search for videos from TikTok API.

        Args:
            keywords (List[str]): Keywords to search for.
            start_date (str): Start date.
            max_size (int): Max number of videos to collect.

        Returns:
            List[Dict[str, str]]: List of videos.
        """
        url: str = "https://open.tiktokapis.com/v2/research/video/query/?fields=id,region_code,like_count,username,video_description,music_id,comment_count,share_count,view_count,effect_ids,hashtag_names,playlist_id,voice_to_text,create_time"  # noqa

        date_ranges: List[tuple[str, str]] = generate_date_ranges(start_date, 100)

        query: Dict[str, Any] = {
            "query": {
                "or": [
                    {
                        "operation": "IN",
                        "field_name": "keyword",
                        "field_values": keywords,
                    },
                    {
                        "operation": "IN",
                        "field_name": "hashtag_name",
                        "field_values": keywords,
                    },
                ]
            },
            "max_count": 100,
        }

        videos: List[Dict[str, str]] = list()

        for date_range in date_ranges:
            query["start_date"] = date_range[0]

            query["end_date"] = date_range[1]

            # Check if we have reached the max size
            if len(videos) >= max_size:
                break

            # Keep querying until there is no more data
            output = self._cursor_iterator(url, query, max_size=max_size)

            if output is not None:
                videos.extend(self._cursor_iterator(url, query, max_size=max_size))

        logging.info(f"Collected {len(videos)} videos.")

        logging.debug("Decoding timestamps...")
        for idx, video in enumerate(videos):
            videos[idx]["create_time"] = datetime.datetime.utcfromtimestamp(
                video["create_time"]  # type: ignore
            ).strftime("%Y-%m-%d")

        return videos

    def get_user(self, username: str) -> Union[Dict[str, Any], None]:
        """Get user data and videos from TikTok API.

        Args:
            username (str): TikTok username.

        Returns:
            Dict[str, str]: User info.
        """
        url: str = "https://open.tiktokapis.com/v2/research/user/info/?fields=display_name,bio_description,avatar_url,is_verified,follower_count,following_count,likes_count,video_count"  # noqa

        query: Dict[str, str] = {
            "username": username,
        }

        data: Union[Dict[str, Any], None] = self.fetch_data(url, query)

        data["videos"] = self._get_user_videos(username)  # type: ignore

        return data

    @retry(
        stop=stop_after_attempt(3),
        wait=wait_fixed(2),
        before=before_log(logger, logging.DEBUG),
    )
    def fetch_data(
        self, url: str, query: Dict[str, Any]
    ) -> Union[Dict[str, Any], None]:
        """Query TikTok API.

        Args:
            url (str): TikTok API url.
            query (Dict[Any, Any]): Custom query. Follow the documentation from https://developers.tiktok.com/doc/research-api-specs-query-videos/

        Returns:
            response (Dict[str, str]): Response from TikTok API.
        """
        headers: Dict[str, str] = self._get_headers()

        try:
            response: Response = requests.post(
                url,
                headers=headers,
                json=query,
                timeout=30,
            )
            response.raise_for_status()  # This will raise a HTTPError for bad responses (4xx and 5xx)
        except requests.RequestException as e:
            logging.error("An error occurred: %s", e)
            return None  # or however you want to handle failures

        return response.json()  # type: ignore

    def get_comments(self, video_id: str) -> List[Dict[str, str]]:
        """Get comments from TikTok API.

        Args:
            video_id (str): TikTok video id.

        Returns:
            List[Dict[str, str]]: List of comments.
        """
        url: str = "https://open.tiktokapis.com/v2/research/video/comment/list/?fields=id,like_count,create_time,text,video_id,parent_comment_id,reply_count"

        query: Dict[str, Any] = {
            "video_id": video_id,
            "max_count": 100,
        }

        comments: List[Dict[str, str]] = list()

        has_more_data: bool = True

        while (
            has_more_data and len(comments) < 1000
        ):  # 1000 is the max number of comments we can get
            response: Union[Dict[str, Any], None] = self.fetch_data(url, query)

            comments.extend(response["data"]["comments"])  # type: ignore

            has_more_data = response["data"]["has_more"]  # type: ignore

            query["cursor"] = response["data"]["cursor"]  # type: ignore

            # Check if we have reached the max size or there is no more data
            if not has_more_data:
                del query["cursor"]
                break

        logging.debug("Decoding timestamps...")
        for idx, comment in enumerate(comments):
            comments[idx]["create_time"] = datetime.datetime.utcfromtimestamp(
                comment["create_time"]  # type: ignore
            ).strftime("%Y-%m-%d")

        return comments

    def _get_user_videos(
        self,
        username: str,
        start_date: str = "2023-01-01",
        max_size: int = 1000,
    ) -> List[Dict[str, Any]]:
        """Get user videos from TikTok API.

        Args:
            username (str): TikTok username.
            start_date (str, optional): Start date. Defaults to "2023-01-01".
            max_size (int, optional): Max number of videos to collect. Defaults to 1000.

        Returns:
            List[Dict[str, str]]: User videos.
        """
        url: str = "https://open.tiktokapis.com/v2/research/video/query/?fields=id,region_code,like_count,username,video_description,music_id,comment_count,share_count,view_count,effect_ids,hashtag_names,playlist_id,voice_to_text,create_time"  # noqa

        date_ranges: List[tuple[str, str]] = generate_date_ranges(start_date, 1000)

        query: Dict[str, Any] = {
            "query": {
                "and": [
                    {
                        "operation": "EQ",
                        "field_name": "username",
                        "field_values": [username],
                    },
                ]
            },
            "max_count": 100,
        }

        videos: List[Dict[str, str]] = list()

        for start_date, end_date in date_ranges:
            query["start_date"] = start_date

            query["end_date"] = end_date

            videos.extend(self._cursor_iterator(url, query, max_size))

        logging.debug("Decoding timestamps...")
        for idx, video in enumerate(videos):
            videos[idx]["create_time"] = datetime.datetime.utcfromtimestamp(
                video["create_time"]  # type: ignore
            ).strftime("%Y-%m-%d")

        return videos

    def _cursor_iterator(
        self, url: str, query: Dict[str, Any], max_size: int = 1000
    ) -> List[Dict[str, str]]:
        """Cursor iterator.

        Args:
            url (str): TikTok API url.
            query (Dict[str, Any]): Custom query. Follow the documentation from https://developers.tiktok.com/doc/research-api-specs-query-videos/
            max_size (int, optional): Max number of videos to collect. Defaults to 1000.

        Returns:
            List[Dict[str, str]]: List of videos.
        """
        has_more_data: bool = True

        data: List[Dict[str, Any]] = list()

        while has_more_data and len(data) < max_size:
            response: Union[Dict[str, Any], None] = self.fetch_data(url, query)

            if response is None:
                return data

            data.extend(response["data"]["videos"])

            has_more_data = response["data"]["has_more"]

            # Check if we have reached the max size or there is no more data
            if not has_more_data:
                return data

            query["cursor"] = response["data"]["cursor"]

            query["search_id"] = response["data"]["search_id"]

        return data

client = TiktokClient()

# %%
# query = {
#     "query": {
#         "and": [
#             {
#                 "operation": "IN",
#                 "field_name": "region_code",
#                 "field_values": ["Austria"],
#             },
#             {
#                 "operation": "EQ",
#                 "field_name": "hashtag_name",
#                 "field_values": ["taylorswift"],
#             },
#         ],
#         "not": [
#             {"operation": "EQ", "field_name": "video_length", "field_values": ["SHORT"]}
#         ],
#     },
#     "max_count": 100,
#     "start_date": "20240101",
#     "end_date": "20240222",
# }

# # url = "https://open.tiktokapis.com/v2/research/video/query/?fields=id,region_code,like_count,username,video_description,music_id,comment_count,share_count,view_count"
# url = "https://open.tiktokapis.com/v2/research/video/query/?fields=id,video_description"

# data = client.query(query=query, url=url)
# Out:
# {'client_key': 'awqs61f0xooywrw9', 'client_secret': '6Ur6CVOMZhA1UUU8rhtRNIx5MoTUlRyQ', 'grant_type': 'client_credentials'}

# %%
data = client.search(keywords=["taylorswift"], start_date="2024-01-01", max_size=10)
# Out:
# {'client_key': 'awqs61f0xooywrw9', 'client_secret': '6Ur6CVOMZhA1UUU8rhtRNIx5MoTUlRyQ', 'grant_type': 'client_credentials'}
# <bound method Response.json of <Response [200]>>
# {'client_key': 'awqs61f0xooywrw9', 'client_secret': '6Ur6CVOMZhA1UUU8rhtRNIx5MoTUlRyQ', 'grant_type': 'client_credentials'}
# <bound method Response.json of <Response [200]>>
# INFO:root:Collected 85 videos.

# %%
data
# Out:
# [{'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'twerk',
#    'free',
#    'dance',
#    'cute',
#    'pretty',
#    'superbowl',
#    'speed',
#    'plane',
#    'trending',
#    'viral',
#    'swifties',
#    'tiktok',
#    'twitter',
#    'foryou',
#    '4u',
#    'trend',
#    'discovery',
#    'bigg',
#    'trendy',
#    'id',
#    'dancechallenge',
#    'albania',
#    'truck',
#    '21savage',
#    'fy',
#    'fyp',
#    'leak',
#    'typ',
#    'planecrash',
#    'planeproblems',
#    'gnb',
#    'asmr',
#    'temu',
#    'britneyarmy',
#    'blowthisup',
#    'xvideos',
#    'surroundsound',
#    'reels',
#    'planechallenge',
#    'ceilingchallenge',
#    'leaks',
#    'traviskelce',
#    'asmrsounds',
#    'toryou',
#    'planelovers',
#    'foryoupage',
#    'foryourpage',
#    'fypage',
#    'lenatheplug',
#    'fypp',
#    'planeedit',
#    'yourrage',
#    'kaicenat',
#    'gnbofficial',
#    'typpppppppppp',
#    'ishowspeed',
#    'ofleaks',
#    'freeleaks',
#    'ishowspeedclipz',
#    'gnboffical',
#    'gnbcollection',
#    'britneyisnotfree',
#    'gnbcouple',
#    'temuleaks',
#    'britneygno',
#    'trendinguser511655123781'],
#   'id': 7330415306508258606,
#   'like_count': 0,
#   'music_id': 7330415422976641834,
#   'video_description': 'Its code 138390143 to see her #gnb #gnbofficial #britneyarmy #britneyisnotfree #britneygno #gnbcouple #gnboffical #gnbcollection #plane #planeedit #planecrash #planechallenge #planelovers #planeproblems planemode #fyp #toryou#ofleaks #temuleaks #temu #free #freeleaks#ishowspeed #asmrsounds #asmr #fyp #viral #speed#trendinguser511655123781 #albania #foryou #ishowspeedclipz #leaks #leak #fy #fypage #viral #typpppppppppp #trending #trendy  #trend #temu #id #surroundsound #ceilingchallenge #dancechallenge #reels #tiktok #dance #Superbowl #swifties #taylorswift #traviskelce #speed##truck" #twitter #xvideos #21savage #kaicenat #ishowspeed #yourrage#lenatheplug #typ #foryoupage #foryourpage #viral #discovery #fypp #trending #twerk #bigg #fyp #4u #blowthisup #cute #leaks #pretty hhhgf',
#   'comment_count': 0,
#   'region_code': 'US',
#   'share_count': 0,
#   'username': 'loki3727',
#   'view_count': 0},
#  {'comment_count': 3,
#   'hashtag_names': ['taylorswift',
#    'taylorswiftsongs',
#    'taylorsversion',
#    'theerastour',
#    'taylorswifterastour'],
#   'id': 7330415285964410144,
#   'music_id': 7330415331829205792,
#   'region_code': 'fr',
#   'username': 'comic_useful',
#   'video_description': 'the willow porfomence on top #taylorsversion #taylorswifterastour #taylorswiftsongs #taylorswift #theerastour',
#   'create_time': '2024-01-31',
#   'like_count': 49,
#   'share_count': 0,
#   'view_count': 28},
#  {'share_count': 0,
#   'view_count': 6,
#   'hashtag_names': ['taylorswift',
#    'collaboration',
#    'dontletthisflop',
#    'capcut'],
#   'id': 7330415271724862762,
#   'like_count': 18,
#   'region_code': 'us',
#   'video_description': 'I love this edit and this girl so much @addie #CapCut #taylorswift #dontletthisflop #collaboration ',
#   'comment_count': 3,
#   'create_time': '2024-01-31',
#   'music_id': 7330415390612294443,
#   'username': 'thatswiftie131313'},
#  {'comment_count': 17,
#   'hashtag_names': ['taylorswift',
#    'nicki',
#    'fyp',
#    'overwatch',
#    'irishtiktok',
#    'floptok',
#    'floptropicaflops'],
#   'id': 7330415265999621409,
#   'region_code': 'fr',
#   'share_count': 0,
#   'view_count': 5,
#   'create_time': '2024-01-31',
#   'like_count': 133,
#   'music_id': 7330415315624053536,
#   'username': 'astiryah',
#   'video_description': '#fyp #overwatch #floptok #irishtiktok #nicki #floptropicaflops #taylorswift '},
#  {'hashtag_names': ['taylorswift',
#    'oneday',
#    'taylorswiftedit',
#    'taylorsversion',
#    'onedayedit',
#    'onedaydavidnicholls',
#    'onedaynetflix',
#    'onedaynetflixedit'],
#   'id': 7330415255614491910,
#   'like_count': 20,
#   'region_code': 'co',
#   'username': 'willestears',
#   'comment_count': 1,
#   'music_id': 6921404355770632194,
#   'share_count': 3,
#   'video_description': '“you weren’t mine to lose” ☁️ (im so ready to cry for them once again in a week!!)  #taylorswift #oneday #onedaynetflix #onedayedit #onedaynetflixedit #onedaydavidnicholls #taylorswiftedit #taylorsversion  ',
#   'view_count': 171,
#   'create_time': '2024-01-31'},
#  {'comment_count': 0,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['lover',
#    'crochet',
#    'crochetbag',
#    'crocheter',
#    'crochettop',
#    'cursosonline',
#    'crochetaddiction',
#    'capcut',
#    'taylorswifttok'],
#   'like_count': 7,
#   'music_id': 7072932874290350894,
#   'region_code': 'ar',
#   'share_count': 0,
#   'username': 'cursoscrochetonline',
#   'view_count': 224,
#   'id': 7330415201352682757,
#   'video_description': '#lover #taylorswifttok #CapCut #crochet #cursosonline #crochetaddiction #crochetbag #crochettop #crocheter '},
#  {'create_time': '2024-01-31',
#   'music_id': 7112561511150668590,
#   'video_description': 'Ken Carson is way better 🥱💀#fyp #imback #kencarson #taylorswiftsucks #imhim ',
#   'comment_count': 3,
#   'hashtag_names': ['imback', 'fyp', 'imhim', 'taylorswiftsucks', 'kencarson'],
#   'id': 7330415169157270814,
#   'like_count': 9,
#   'region_code': 'us',
#   'share_count': 0,
#   'username': 'vsp_karter',
#   'view_count': 8},
#  {'share_count': 0,
#   'username': 'coconut.girlies0',
#   'video_description': 'Can school just be over already🥰 #coconut #coconutgirl #coconut.girlies0 #beach #summer #summer2024 #fyp #fypシ #foryoupage #viral #viralvideo #foryou #hawaii #summervibes #wedidnotcopyanyone #summertiktok #ocean #taylorswift #fyppp ',
#   'hashtag_names': ['taylorswift',
#    'summer',
#    'beach',
#    'ocean',
#    'hawaii',
#    'viral',
#    'foryou',
#    'summervibes',
#    'coconut',
#    'viralvideo',
#    'fyp',
#    'coconutgirl',
#    'foryoupage',
#    'summertiktok',
#    'wedidnotcopyanyone',
#    'fyppp',
#    'fypシ',
#    'summer2024'],
#   'id': 7330415161381113130,
#   'music_id': 7292202589486091038,
#   'region_code': 'us',
#   'comment_count': 14,
#   'create_time': '2024-01-31',
#   'like_count': 61,
#   'view_count': 94},
#  {'id': 7330415141319789870,
#   'region_code': 'us',
#   'share_count': 0,
#   'video_description': 'We did it! @lululemon we love you🫶 #run #running #eveningroutine #eveningrun #coupletok #ootd #OOTD #outfit #runoutfit #runningoutfit #runner #training #workout #workingout #couplestiktok #couplesoftiktok #lululemon #gymshark #hokas #outfitideas #outfitinspo #athlesuire #athlesiurewear #comeonarunwithme #goonarunwithme #comeonarunwithus #relationship #couplegoals #fyp #viral #lookgoodfeelgood #elevatorootd #apartmentliving #apartmentlife #goals #philly #philadelphia #phillytok #phillytiktok #philadelphian #philadelphians #philadelphiaeagles #philadelphia76ers #ootdfashion #fashion #lululemonaddict #superbowl #football #sports #sporty #sportswear #chiefs #49ers #taylorswift #kansascitychiefs ',
#   'voice_to_text': "we're back with another elevator OOTD I have Lulu Lulu um Lululemon hokas  and I have my hair in a bun but probably won't stay you go um gym shark Lulu Hokas  Yay how long am I here shooting for we are shooting for 3 3 miles let's get it",
#   'view_count': 43,
#   'comment_count': 0,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'goals',
#    'workout',
#    'football',
#    'sports',
#    'run',
#    'running',
#    'superbowl',
#    'fashion',
#    'training',
#    'ootd',
#    'relationship',
#    'outfit',
#    'philadelphia',
#    'philly',
#    'viral',
#    'sporty',
#    'runner',
#    'workingout',
#    'couplegoals',
#    '49ers',
#    'lululemon',
#    'fyp',
#    'chiefs',
#    'outfitideas',
#    'sportswear',
#    'philadelphiaeagles',
#    'apartmentlife',
#    'lookgoodfeelgood',
#    'kansascitychiefs',
#    'eveningroutine',
#    'outfitinspo',
#    'gymshark',
#    'hokas',
#    'runningoutfit',
#    'apartmentliving',
#    'philadelphia76ers',
#    'eveningrun',
#    'ootdfashion',
#    'couplestiktok',
#    'couplesoftiktok',
#    'philadelphians',
#    'philadelphian',
#    'lululemonaddict',
#    'coupletok',
#    'phillytiktok',
#    'athlesuire',
#    'runoutfit',
#    'comeonarunwithme',
#    'athlesiurewear',
#    'phillytok',
#    'elevatorootd',
#    'goonarunwithme',
#    'comeonarunwithus'],
#   'like_count': 18,
#   'music_id': 7320403755933124609,
#   'username': 'hannah_cui'},
#  {'hashtag_names': ['taylorswift',
#    'funny',
#    'epic',
#    'money',
#    'delicious',
#    'oops',
#    'epicfail',
#    'x',
#    'bank',
#    'lost',
#    'wealth',
#    'cash',
#    'richman',
#    'billionaire',
#    'duet',
#    'twitter',
#    'ceo',
#    'court',
#    'shares',
#    'poorman',
#    'assets',
#    'corporate',
#    'elonmusk'],
#   'like_count': 38,
#   'username': 'a.b.fritz.joy',
#   'region_code': 'us',
#   'share_count': 0,
#   'video_description': '#duet with @🔥✨HausofPetty✨🔥 #twitter #x #elonmusk #billionaire #corporate #ceo #lost #shares #poorman #richman #funny #taylorswift #oops #court #epic #epicfail #bank #money #cash #assets #wealth #delicious ',
#   'view_count': 3,
#   'comment_count': 2,
#   'create_time': '2024-01-31',
#   'id': 7330415115386342686,
#   'music_id': 7330222563395767082,
#   'voice_to_text': "good morning you glorious bitch it's time to wake up make some coffee there as fuckery afoot Lonnie Muscachino was really going through it on his little piece of shit platform yesterday we figured out why this morning and I love this for him if you don't know Tesla like many other businesses in the United States are incorporated in Delaware due to their tax issues they've got really good tax laws and also they don't pay taxes so obviously Tesla was incorporated there well Alani and Espertino while the back was being sued and he lost he lost big boy the elonnie and Muscartina paid him the tune of about $56 billion from shares now I don't know all the details about it but his board which is made up of friends and his brother on Tesla just said no and they won The Delaware Court of Chancery has rescinded Elani Muscartina's unfathomable 56 billion received from the Tesla board these were shears should that these were shares uses collateral for US 44 billion Twitter purchase which is now worth practically zero melodia Miss Martina lost 100 fucking billion dollars do you know who did it Taylor Swift haha"},
#  {'share_count': 0,
#   'username': 'ghaliagems',
#   'like_count': 9,
#   'music_id': 7136696462645693189,
#   'region_code': 'do',
#   'id': 7330415105630424326,
#   'video_description': '#taylorswifttok #taylorswift #swiftie #joyeria #emprendedor #tendenciadejoveria #elevatulookconaccesorios #emprendiendo #ghaliagems #fyp #etiquetala #menciona #jewelry #estilo #tendencia',
#   'view_count': 101,
#   'comment_count': 2,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'jewelry',
#    'swiftie',
#    'fyp',
#    'estilo',
#    'tendencia',
#    'emprendedor',
#    'joyeria',
#    'menciona',
#    'etiquetala',
#    'emprendiendo',
#    'taylorswifttok',
#    'elevatulookconaccesorios',
#    'ghaliagems',
#    'tendenciadejoveria']},
#  {'comment_count': 19,
#   'hashtag_names': ['taylorswift',
#    'funny',
#    'f',
#    'fu',
#    'fox',
#    'swiftie',
#    'karma',
#    'vote',
#    'fyp',
#    'voteblue',
#    '2024',
#    'fypage',
#    'foxnewsisajoke',
#    'fypシ',
#    'capcut',
#    'taylorswifttok'],
#   'id': 7330415101830286623,
#   'like_count': 127,
#   'region_code': 'us',
#   'share_count': 0,
#   'username': 'stephaniemarie4752',
#   'create_time': '2024-01-31',
#   'music_id': 7253573833620195329,
#   'video_description': '#CapCut 💙 #taylorswift #taylorswifttok #swiftie #fox #foxnewsisajoke #voteblue #funny #karma #vote #2024 #f #fyp #fypシ #fypage #fu ',
#   'view_count': 18},
#  {'username': 'cxlbyzfx',
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'edit',
#    'same',
#    'taylor',
#    'swift',
#    'swiftie',
#    'foryou',
#    'triplets',
#    'recreate',
#    'colby',
#    'taylorswiftconcert',
#    'fyp',
#    'samgolbach',
#    'brock',
#    'velocity',
#    'construction',
#    'coreysherer',
#    'arrondoh',
#    'katrinastuart',
#    'jakewebber',
#    'golbach',
#    'colbybrockedit',
#    'samgolbachedit',
#    'velocityedit',
#    'taylorswifttickets',
#    'foryoupage',
#    'jakewebberedit',
#    'katrinastuartedit',
#    'tarayummy',
#    'tarayummyedit',
#    'coreyshereredit',
#    'arrondohedit',
#    'xcyba',
#    'timewarpscan',
#    'sturniolotriplets',
#    'nicksturniolo',
#    'mattsturniolo',
#    'chrissturniolo',
#    'chrissturnioloedit',
#    'nicksturnioloedit',
#    'thesturniolotriplets',
#    'thesturniolotripletsedit',
#    'brocksociety',
#    'mattstunrioloedit',
#    'brockscc',
#    'cxlbyzfx'],
#   'music_id': 7330415232785451818,
#   'region_code': 'us',
#   'share_count': 0,
#   'video_description': '#TARAYUMMY|#brocksociety|i fixed my blur finally🙏| #velocity#velocityedit #fyp #foryou #foryoupage #TimeWarpScan #recreate #same #edit#taylorswift #swiftie #taylor #swift#taylorswifttickets #taylorswiftconcert#samgolbach #colbybrockedit #brock#brockscc#colby #golbach #samgolbachedit #mattsturniolo#mattstunrioloedit #chrissturniolo#chrissturnioloedit #nicksturniolo#nicksturnioloedit #thesturniolotriplets #thesturniolotripletsedit #triplets#sturniolotriplets #jakewebber#jakewebberedit#tarayummy#tarayummyedit #katrinastuart#katrinastuartedit #coreysherer#coreyshereredit#arrondoh#arrondohedit#construction#xcyba#brocksociety#cxlbyzfx ',
#   'view_count': 15,
#   'comment_count': 22,
#   'id': 7330415098571345194,
#   'like_count': 78},
#  {'hashtag_names': ['taylorswift',
#    'britneyspears',
#    'christmas',
#    'summer',
#    'memories',
#    'texas',
#    'houston',
#    'houstontx',
#    'childhoodmemories',
#    'nostalgia',
#    'tiktokholidays',
#    'vintagechristmas',
#    'nostalgiachristmas'],
#   'id': 7330415098462244138,
#   'music_id': 6903923784021985282,
#   'video_description': '#TikTokHolidays #houstontx #houston #vintagechristmas  #christmas #texas #nostalgia #nostalgiachristmas #memories #childhoodmemories #summer #taylorswift #britneyspears ',
#   'create_time': '2024-01-31',
#   'like_count': 96,
#   'region_code': 'us',
#   'share_count': 0,
#   'username': 'cranberryschristmas',
#   'view_count': 37,
#   'comment_count': 4},
#  {'hashtag_names': ['taylorswift',
#    'tswift',
#    'swifties',
#    'singalong',
#    'ts',
#    'swiftie',
#    'poetry',
#    'lyricalgenius',
#    'evermore',
#    'taylorsversion',
#    'taylorswiftsingalong',
#    '🌈',
#    'swiftok',
#    'swifttok',
#    'swiftietok',
#    'evermorestan',
#    'swifttoker',
#    'swiftoker',
#    'illgobacktola',
#    'erastourtaylorswift',
#    'erastour'],
#   'id': 7330415096931306795,
#   'region_code': 'us',
#   'video_description': '#evermore #swiftie #swifties #swiftietok #evermorestan #tswift #taylorswift #taylorswiftsingalong #singalong #poetry #lyricalgenius #illgobacktola #taylorsversion #erastour #erastourtaylorswift #ts #swifttok #swiftok #swiftoker #swifttoker #🌈 ',
#   'comment_count': 7,
#   'create_time': '2024-01-31',
#   'effect_ids': ['82237165'],
#   'like_count': 160,
#   'music_id': 7105739055396113157,
#   'share_count': 0,
#   'username': 'coryneugz',
#   'view_count': 15},
#  {'create_time': '2024-01-31',
#   'id': 7330415067093093664,
#   'like_count': 3,
#   'music_id': 7311488954557483009,
#   'region_code': 'gb',
#   'video_description': '#tiktokpoll #taylorswift #hereatlastofficial @Taylor Swift ',
#   'comment_count': 1,
#   'hashtag_names': ['taylorswift', 'tiktokpoll', 'hereatlastofficial'],
#   'share_count': 0,
#   'username': 'stitchlover910',
#   'view_count': 5},
#  {'comment_count': 1,
#   'create_time': '2024-01-31',
#   'id': 7330415053633719598,
#   'like_count': 4,
#   'region_code': 'us',
#   'username': 'editssxchloee',
#   'hashtag_names': ['taylorswift',
#    'july',
#    'like',
#    'aly',
#    'yes',
#    'ella',
#    'edits',
#    'ily',
#    'dancemoms',
#    'viral',
#    'ts',
#    'chloe',
#    '2',
#    'fyp',
#    'chlobird',
#    'dontflop',
#    'barnies',
#    'ashleybarnes',
#    'took7hourstomake',
#    'zyxcba',
#    'alysloan',
#    'twolovehearts',
#    'editssxchloee'],
#   'music_id': 7330415185519201067,
#   'share_count': 0,
#   'video_description': 'I hate this 😾 #editssxchloee #ashleybarnes #barnies #aly #alysloan #edits #ts #taylorswift #dancemoms #2 #twolovehearts #fyp #like #dontflop #took7hourstomake #july #yes #ella #chlobird #chloe #ily #viral #zyxcba ',
#   'view_count': 0},
#  {'id': 7330415036252376362,
#   'share_count': 0,
#   'comment_count': 1,
#   'create_time': '2024-01-31',
#   'music_id': 7330415419565542187,
#   'region_code': 'us',
#   'username': 'lesleeey13',
#   'video_description': 'i love the way he talks about her and their relationship 🥹 #taylorswift #swifttok #swiftie #taylorandtravis #taylorswifttraviskelce #taylorswiftnfl #taylorswiftchiefs ',
#   'view_count': 168,
#   'hashtag_names': ['taylorswift',
#    'swiftie',
#    'swifttok',
#    'taylorandtravis',
#    'taylorswiftnfl',
#    'taylorswifttraviskelce',
#    'taylorswiftchiefs'],
#   'like_count': 95},
#  {'id': 7330415027922455850,
#   'like_count': 66,
#   'share_count': 0,
#   'username': 'colegardner8',
#   'view_count': 16,
#   'comment_count': 8,
#   'hashtag_names': ['taylorswift', 'chiefs', 'capcut', 'butteredsausage'],
#   'region_code': 'us',
#   'video_description': 'Give us a break already!  #chiefs #taylorswift #butteredsausage #capcut ',
#   'create_time': '2024-01-31',
#   'music_id': 7330415128061528875},
#  {'hashtag_names': ['taylorswift',
#    'loverboy',
#    'dogs',
#    'lover',
#    'puppylove',
#    'valentines',
#    'puppies',
#    'aussies',
#    'aussie',
#    'oklahoma',
#    'puppiesoftiktok'],
#   'region_code': 'us',
#   'share_count': 0,
#   'username': 'copperlanepuppies',
#   'video_description': "𝕀'𝕝𝕝 𝕗𝕠𝕣𝕖𝕧𝕖𝕣 𝕓𝕖 𝕝𝕠𝕧𝕖𝕤𝕥𝕣𝕦𝕔𝕜 𝕠𝕧𝕖𝕣 𝕥𝕙𝕚𝕤 𝕓𝕠𝕪😍🥰 🤍 ‘dana is from @divinepups.co - Use code 𝕔𝕠𝕡𝕡𝕖𝕣𝕝𝕒𝕟𝕖𝟙𝟝 at checkout to save😍 #lover #loverboy #valentines #puppies #puppiesoftiktok #puppylove #aussies #aussie #dogs #dogs #oklahoma #taylorswift",
#   'comment_count': 2,
#   'create_time': '2024-01-31',
#   'id': 7330415011623439662,
#   'like_count': 113,
#   'music_id': 7211414788360898561,
#   'view_count': 4},
#  {'video_description': 'WHY UMG WHY ??? #umg #taylorswift #sza ',
#   'comment_count': 2,
#   'create_time': '2024-01-31',
#   'like_count': 62,
#   'region_code': 'us',
#   'share_count': 0,
#   'hashtag_names': ['taylorswift', 'sza', 'umg'],
#   'id': 7330414980170255658,
#   'music_id': 7262784807749438251,
#   'username': 'ripvinepage',
#   'view_count': 4},
#  {'comment_count': 0,
#   'create_time': '2024-01-31',
#   'id': 7330414978207468843,
#   'music_id': 7330415124560268074,
#   'region_code': 'us',
#   'username': 'alltoowellattire',
#   'view_count': 33,
#   'hashtag_names': ['taylorswift',
#    'lover',
#    'bracelet',
#    'jewelry',
#    'swifties',
#    'swiftie',
#    'midnights',
#    'taylorswiftconcert',
#    'reputation',
#    'bracelets',
#    'taylornation',
#    'taylurking',
#    'friendshipbracelets',
#    'etsy',
#    'taylorswift13',
#    'swiftiesforever',
#    'taylorsversion',
#    'yoyok',
#    'redtv',
#    'bracelettrading',
#    'swiftiemerch',
#    '1989tv',
#    'speaknowtv',
#    'taylorswiftshop',
#    'theerastour',
#    'taylorswifterastour',
#    'tstheerastour'],
#   'like_count': 7,
#   'share_count': 0,
#   'video_description': 'Make a folklore bracelet with me (fun fact: betty is my fav t swift song\U0001fa77)  #taylorswift #theerastour #tstheerastour #friendshipbracelets #yoyok #taylorswift13 #taylorswifterastour #taylorswiftconcert #taylornation #taylorsversion #bracelettrading #etsy #jewelry #bracelets #bracelet #taylurking #swiftie #swifties #swiftiesforever #swiftiemerch #taylorswiftshop #midnights #redtv #reputation #swiftie #1989tv #lover #speaknowtv #taylorswift13 '},
#  {'create_time': '2024-01-31',
#   'id': 7330414976756141318,
#   'region_code': 'mx',
#   'share_count': 2,
#   'video_description': 'Noticia de último momento!! No me imsgino una plataforma que no tenga estos audios! Ayudaaa  #music #badbunny #taylorswift #tiktok ',
#   'comment_count': 9,
#   'like_count': 96,
#   'music_id': 7330414985906309894,
#   'username': '_risomi_',
#   'view_count': 897,
#   'hashtag_names': ['taylorswift', 'music', 'tiktok', 'badbunny']},
#  {'like_count': 4237,
#   'music_id': 7330415150069025578,
#   'region_code': 'us',
#   'share_count': 15,
#   'username': 'alyssa_weston',
#   'video_description': 'Day 1 of turning my coworkers into Swifties before the Super Bowl! 👀 #taylorswift #taylorsversion #taylornation #tayvis #tayvisbowl #reactingtotaylorswift #listeningtotaylorswiftfirsttime #turningintoswiftie #erastour #SuperBowl #SuperBowlLVIII #reactingtofolklore #listeningtofolklore #folklore #mytearsricochet #ariasorganization ',
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'superbowl',
#    'taylornation',
#    'folklore',
#    'taylorsversion',
#    'tayvis',
#    'superbowllviii',
#    'mytearsricochet',
#    'listeningtofolklore',
#    'erastour',
#    'reactingtotaylorswift',
#    'ariasorganization',
#    'turningintoswiftie',
#    'tayvisbowl',
#    'listeningtotaylorswiftfirsttime',
#    'reactingtofolklore'],
#   'id': 7330414959924596014,
#   'view_count': 8142,
#   'comment_count': 149},
#  {'id': 7330414949635853610,
#   'like_count': 1,
#   'region_code': 'us',
#   'share_count': 0,
#   'view_count': 2,
#   'comment_count': 0,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'football',
#    'vegas',
#    'trending',
#    'viral',
#    'followback',
#    'viralvideo',
#    '49ers',
#    'chiefs',
#    'biggame',
#    'chiefsnation',
#    'tiktokfamous',
#    '10000followers10days',
#    'superbowl2024',
#    'madden2025',
#    'kelceswift'],
#   'music_id': 7243697117041313793,
#   'username': 'togetherwedomore',
#   'video_description': '#superbowl2024 #taylorswift #football #trending #kelceswift #viralvideo #followback #madden2025 #biggame #49ers #chiefs #chiefsnation #tiktokfamous #viral #10000followers10days #vegas '},
#  {'like_count': 58,
#   'share_count': 0,
#   'video_description': '@Taylor Swift #TaylorSwift #FoxNews #Defamation #Consequences #StrongWoman #RepublicanLiars #TrumpRepublicanCrimeParty #VoteBlueSaveDemocracy #Swifties #FYP',
#   'view_count': 39,
#   'comment_count': 32,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'swifties',
#    'fyp',
#    'strongwoman',
#    'consequences',
#    'foxnews',
#    'defamation',
#    'republicanliars',
#    'votebluesavedemocracy',
#    'trumprepublicancrimeparty'],
#   'id': 7330414929784163627,
#   'music_id': 7330415066904333098,
#   'region_code': 'us',
#   'username': 'boston_grandpa'},
#  {'username': 'cookietherookiee',
#   'video_description': '#traviskelce says he can’t go to the #grammys to support #taylorswift  #traviskelcetaylorswift ',
#   'view_count': 133,
#   'create_time': '2024-01-31',
#   'region_code': 'tr',
#   'share_count': 15,
#   'like_count': 47,
#   'music_id': 7330414926048545541,
#   'comment_count': 0,
#   'hashtag_names': ['taylorswift',
#    'grammys',
#    'traviskelce',
#    'traviskelcetaylorswift'],
#   'id': 7330414911593532677},
#  {'music_id': 7330415026933320491,
#   'region_code': 'us',
#   'view_count': 127,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'viralvideo',
#    'tripletthreat',
#    'fyp',
#    'swiftie4ever',
#    'blowthisup',
#    'taylorswiftedit',
#    'shadowbanned',
#    'fypdoesntwork',
#    'xzyabc',
#    'capcut',
#    'theerastour'],
#   'id': 7330414899476172075,
#   'username': 'taylorswiftreputation0',
#   'video_description': 'I think ima take TAYLOR #taylorswift #fyp #xzyabc #shadowbanned #theerastour #swiftie4ever #blowthisup #tripletthreat #fypdoesntwork #viralvideo #taylorswiftedit #CapCut ',
#   'comment_count': 5,
#   'like_count': 68,
#   'share_count': 0},
#  {'music_id': 7294449191711197186,
#   'region_code': 'us',
#   'share_count': 0,
#   'video_description': 'For all of of those niners fans looking to rain on Taylor Swifts parade this is the short for you! Order now to get it in time for the game! #superbowl #49ers #49ersfaithful #nfl #taylorswift #swiftie #sanfrancisco #sanfrancisco49ers #niners #goniners ',
#   'id': 7330414898498932014,
#   'like_count': 31,
#   'hashtag_names': ['taylorswift',
#    'sanfrancisco',
#    'superbowl',
#    'nfl',
#    'swiftie',
#    '49ers',
#    'goniners',
#    'niners',
#    '49ersfaithful',
#    'sanfrancisco49ers'],
#   'username': 'not.vintage.tshirts',
#   'view_count': 6,
#   'comment_count': 3,
#   'create_time': '2024-01-31'},
#  {'id': 7330414888193395973,
#   'share_count': 0,
#   'view_count': 297,
#   'comment_count': 0,
#   'hashtag_names': ['taylorswift',
#    'kendricklamar',
#    'kendrick',
#    'damn',
#    '1989'],
#   'music_id': 7226837107929533211,
#   'region_code': 'br',
#   'username': 'jpkkkkkj0',
#   'video_description': '#kendrick #kendricklamar #damn#taylorswift #1989 ',
#   'create_time': '2024-01-31',
#   'like_count': 12},
#  {'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift', 'duet'],
#   'region_code': 'us',
#   'share_count': 0,
#   'view_count': 43,
#   'comment_count': 0,
#   'like_count': 20,
#   'music_id': 7330099277055773483,
#   'username': 'b_nice42',
#   'video_description': '#duet with @Pearlmania500 #TaylorSwift ',
#   'id': 7330414882304707882},
#  {'video_description': '2024 camrea roll so far 🌶️\U0001fa75#2024 #taylorswift #febuary #january #travel #crazy #love #4lifers ',
#   'comment_count': 3,
#   'like_count': 53,
#   'music_id': 7141925053033302830,
#   'region_code': 'au',
#   'share_count': 0,
#   'username': 'takayaespin',
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'love',
#    'crazy',
#    'travel',
#    'january',
#    'febuary',
#    '4lifers',
#    '2024'],
#   'id': 7330414863350598913,
#   'view_count': 632},
#  {'comment_count': 6,
#   'hashtag_names': ['taylorswift', 'fyp', 'kcchiefs'],
#   'id': 7330414853544332587,
#   'like_count': 83,
#   'music_id': 7314863233305774890,
#   'username': 'dumb.blonde409',
#   'video_description': 'cause why yall crying ? #fyp #kcchiefs #taylorswift ',
#   'create_time': '2024-01-31',
#   'region_code': 'us',
#   'share_count': 0,
#   'view_count': 3},
#  {'share_count': 2,
#   'view_count': 1087,
#   'comment_count': 6,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift', 'harrystyles', 'hazza', 'hslot'],
#   'music_id': 7330414857021328134,
#   'video_description': 'lo amo tanto, tanto<3  #harrystyles #hslot #taylorswift #hazza ',
#   'id': 7330414832262335749,
#   'like_count': 172,
#   'region_code': 'mx',
#   'username': 'halotal'},
#  {'region_code': 'us',
#   'username': 'kelsieleewarren',
#   'video_description': "how'd I miss this!! @jack antonoff AND @FLETCHER pictured together?! 🔥💀 and all the other stuff this week hmm 🔍 KARMA BRINGS ALL MY FRIENDS TO THE SUMBIT 🌄👀 jack is starting his own record label #karmabringsallmyfriendstothesummit #dontbesuspicious #fletcher #erasofus #erasofusfletcher #leadmeonfletcher #whydontyoujustleadmeon #inthesearchofantidote #antidote #jackantanoff #thebleachers #jackantonoffandtaylorswift #taylorswift #alltoowell #redtaylorsversion  #1989TaylorsVersion #noexplanationjustreputation #reputationtaylorsversion #friendofdorothea #bettytaylorswift #lgbtq #lgbt🌈 #proud #taylorswifteastereggs #taylorswifteasteregg #taylorsversion #123lgb #newyork #newyorkcity #swifties #swiftie #swifttok #swiftok #swiftietiktok #swiftietok #swiftie4ever #taylornation #youtube #instagram #fyp  @Taylor Nation @Taylor Swift ",
#   'hashtag_names': ['taylorswift',
#    'newyork',
#    'instagram',
#    'youtube',
#    'newyorkcity',
#    'proud',
#    'swifties',
#    'swiftie',
#    'lgbtq',
#    'antidote',
#    'fyp',
#    'thebleachers',
#    'taylornation',
#    'fletcher',
#    'alltoowell',
#    'swiftie4ever',
#    'taylorsversion',
#    'jackantanoff',
#    'dontbesuspicious',
#    'lgbt🌈',
#    '123lgb',
#    'swiftok',
#    'swiftietiktok',
#    'swifttok',
#    'swiftietok',
#    'bettytaylorswift',
#    'taylorswifteastereggs',
#    '1989taylorsversion',
#    'redtaylorsversion',
#    'reputationtaylorsversion',
#    'taylorswifteasteregg',
#    'noexplanationjustreputation',
#    'friendofdorothea',
#    'jackantonoffandtaylorswift',
#    'erasofus',
#    'erasofusfletcher',
#    'leadmeonfletcher',
#    'karmabringsallmyfriendstothesummit',
#    'whydontyoujustleadmeon',
#    'inthesearchofantidote'],
#   'music_id': 7317339589768955905,
#   'id': 7330414811018284318,
#   'like_count': 33,
#   'share_count': 0,
#   'view_count': 34,
#   'comment_count': 1,
#   'create_time': '2024-01-31'},
#  {'hashtag_names': ['shopsmall',
#    'recordstore',
#    'recordcollector',
#    'newvinyl',
#    'vinyltok',
#    'vinyldisplay',
#    'criminalrecordsatl',
#    'vylumi',
#    'taylorswiftmidnights'],
#   'id': 7330414792466812203,
#   'region_code': 'us',
#   'share_count': 0,
#   'view_count': 31,
#   'comment_count': 9,
#   'create_time': '2024-01-31',
#   'like_count': 285,
#   'music_id': 6928470186467018753,
#   'username': 'criminalrecordsatl',
#   'video_description': 'so much to love about this vinyl display! you can pick one up in store!@Vylümi  #criminalrecordsatl #recordstore #vinyltok #shopsmall #newvinyl #vinyldisplay #vylumi #recordcollector #taylorswiftmidnights '},
#  {'video_description': 'love ya @mathilda 💞 | #zeesmultiix #fyp #foryoupage #fyy #edit #bestfriends #bff #top3 #titanic #suicidesquad #theflash #youngroyals #melissabenoist #benjaminwadesworth #taylorswift #abba #harrywells #marcuslopez #westallen #jackandrose #athousandboykisses #agoodgirlsguidetomurder  @Jael @marta <3 @~ Chloe ( Lana’s version ) ~ @Frieda @♡숩♡|𒈔𒉽𒈔 @Israel Echikwu @district.everdeen @Mafia_ musteata @Lily (Taylor’s version) @𝐣𝐮𝐥𝐢𝐞 @tv series 🫀🎬 @𝔍𝔬𝔫𝔞𝔱𝔥𝔞𝔫\u2002۵ @sav (damon’s version) @˗ˏˋ 𝖊𝖑𝖑𝖆 ´ˎ˗ @Archer.aep @Gabby🧣⸆⸉ @g ✧ @clo ౨ৎ  ',
#   'hashtag_names': ['taylorswift',
#    'edit',
#    'bestfriends',
#    'bff',
#    'abba',
#    'titanic',
#    'theflash',
#    'jackandrose',
#    'fyp',
#    'top3',
#    'westallen',
#    'fyy',
#    'melissabenoist',
#    'marcuslopez',
#    'harrywells',
#    'foryoupage',
#    'youngroyals',
#    'agoodgirlsguidetomurder',
#    'athousandboykisses',
#    'benjaminwadesworth',
#    'zeesmultiix',
#    'suicidesquad'],
#   'music_id': 7245864080614853418,
#   'region_code': 'ch',
#   'share_count': 6,
#   'username': 'zees.multiix',
#   'comment_count': 44,
#   'create_time': '2024-01-31',
#   'id': 7330414789258251552,
#   'like_count': 500,
#   'view_count': 490},
#  {'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'deanforester',
#    'roryandjess',
#    'rorygilmore',
#    'jessmariano',
#    'deanandrory'],
#   'like_count': 26,
#   'music_id': 7330414805868907270,
#   'region_code': 'br',
#   'video_description': '🤍#jessmariano #roryandjess #rorygilmore #deanforester #deanandrory #taylorswift ',
#   'comment_count': 1,
#   'share_count': 1,
#   'username': 'jessmarianoo',
#   'view_count': 289,
#   'id': 7330414782589226246},
#  {'video_description': '#taylorswift 💃🏼 #traviskelce 🕺🏻 #lover #nfl #chiefs #singer #dailycuties #et #repost ',
#   'view_count': 90,
#   'comment_count': 1,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'repost',
#    'lover',
#    'nfl',
#    'singer',
#    'et',
#    'chiefs',
#    'traviskelce',
#    'dailycuties'],
#   'share_count': 0,
#   'username': 'sparkly_ladyk',
#   'id': 7330414777598020907,
#   'like_count': 70,
#   'music_id': 7211414788360898561,
#   'region_code': 'us'},
#  {'hashtag_names': ['taylorswift',
#    'swifties',
#    'swiftie',
#    'taylornation',
#    'fouryoupage',
#    'swifttok',
#    'antoniavuelve💔'],
#   'music_id': 7330414775816227590,
#   'region_code': 'co',
#   'share_count': 0,
#   'username': 'taylormylovea',
#   'video_description': 'quedo horrible,  pero el punto esque la amo , ella es la que me llena el vacío en mi corazón,  mi taysita linda,  la adoro , siempre la amaré,  y la amo , mi taysita,  ni número 1 , mi mundo , TODO , la adoro 💗 #swifties #taylorswift #taylornation #antoniavuelve💔 #swifttok #fouryoupage #swiftie ',
#   'view_count': 368,
#   'comment_count': 13,
#   'id': 7330414755414428933,
#   'like_count': 56,
#   'create_time': '2024-01-31'},
#  {'id': 7330414752230870277,
#   'region_code': 'br',
#   'share_count': 1,
#   'username': 'amortaylorswift13',
#   'view_count': 880,
#   'comment_count': 5,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'tiktok',
#    'fy',
#    'seguidores',
#    'brasil🇧🇷',
#    'fypシ',
#    'capcut',
#    'fypシ゚viral',
#    'lavanderhazetaylorswift',
#    'amortaylorswift'],
#   'like_count': 95,
#   'music_id': 7258690146718681882,
#   'video_description': 'Lavander Haze-Taylor Swifts #taylorswift #capcut #tiktok #seguidores #fy #fypシ゚viral #fypシ #fypシ #amortaylorswift #brasil🇧🇷 #lavanderhazetaylorswift '},
#  {'share_count': 197,
#   'comment_count': 700,
#   'create_time': '2024-01-31',
#   'id': 7330414738276502814,
#   'like_count': 5051,
#   'music_id': 7330414876625570590,
#   'hashtag_names': ['taylorswift',
#    'edit',
#    'football',
#    'superbowl',
#    'nfl',
#    'viral',
#    'swifty',
#    'espn',
#    'niners',
#    'purdy',
#    '13',
#    'fypシ',
#    'brockpurdy',
#    'superbowl2024'],
#   'region_code': 'us',
#   'username': 'projectedits2',
#   'video_description': 'It is really a good number #13 #purdy #nfl #edit #superbowl #superbowl2024 #taylorswift #brockpurdy #fypシ #niners #espn #football #swifty #viral ',
#   'view_count': 8692},
#  {'like_count': 1,
#   'username': 'dodi15977',
#   'comment_count': 0,
#   'create_time': '2024-01-31',
#   'music_id': 7156826385225353217,
#   'region_code': 'mx',
#   'share_count': 4,
#   'video_description': '#taylornation #taylorswift ',
#   'view_count': 44,
#   'hashtag_names': ['taylorswift', 'taylornation'],
#   'id': 7330414723386625285},
#  {'comment_count': 3,
#   'create_time': '2024-01-31',
#   'id': 7330414692403367211,
#   'like_count': 41,
#   'username': 'adventuresofadisneydad',
#   'video_description': '“I’m going to Disney World” could be taken to a whole new level if Travis Kelce wins the Super Bowl MVP… I *think* it would be a little crowded that day… *if* it happened… which is not unrealistic.  #disneyworld #Super Bowl #chiefs #taylorswift #traviskelce ',
#   'view_count': 127,
#   'hashtag_names': ['taylorswift',
#    'super',
#    'disneyworld',
#    'chiefs',
#    'traviskelce'],
#   'music_id': 112470437,
#   'region_code': 'us',
#   'share_count': 0},
#  {'create_time': '2024-01-31',
#   'like_count': 99,
#   'music_id': 7087228546954873605,
#   'share_count': 0,
#   'video_description': '#cowboylikeme #cowboylikemesupremacy #cowboylikemetaylorswift #swifttok #swiftiesforever #swiftiesunite #taylorsversion #🌈🌈 #taylorswift #underratedsongs #underratedtaylorswiftsongs #evermore #evermoretaylorswift #evermorestan #evermorealbum ',
#   'view_count': 2,
#   'comment_count': 20,
#   'effect_ids': ['82237214'],
#   'hashtag_names': ['taylorswift',
#    'cowboylikeme',
#    'evermore',
#    'swiftiesunite',
#    'swiftiesforever',
#    'taylorsversion',
#    'underratedsongs',
#    '🌈🌈',
#    'underratedtaylorswiftsongs',
#    'swifttok',
#    'evermoretaylorswift',
#    'evermorealbum',
#    'evermorestan',
#    'cowboylikemesupremacy',
#    'cowboylikemetaylorswift'],
#   'id': 7330414692193684779,
#   'region_code': 'us',
#   'username': 'coryneugz'},
#  {'view_count': 892,
#   'id': 7330414690884963589,
#   'video_description': '#vamostaylorswiftmipatrona❤️\u200d #taylor #taylorsacareptv👹 #laseras #taylorswift #taytay🦋 #taylorteamo #parati #fyb #fyr 💕💕',
#   'hashtag_names': ['taylorswift',
#    'taylor',
#    'fyb',
#    'parati',
#    'fyr',
#    'taylorteamo',
#    'laseras',
#    'taytay🦋',
#    'taylorsacareptv👹',
#    'vamostaylorswiftmipatrona❤️\u200d'],
#   'like_count': 112,
#   'music_id': 7330414699420388102,
#   'region_code': 'ar',
#   'share_count': 0,
#   'username': 'swiftie_1432',
#   'comment_count': 6,
#   'create_time': '2024-01-31'},
#  {'create_time': '2024-01-31',
#   'like_count': 106,
#   'music_id': 279408821033394176,
#   'region_code': 'us',
#   'video_description': 'The Super Bowl we all deserve. #nflmemes #smokinjay #49ers #Chiefs #Superbowl58 #nflfootball #nflplayoffs #bears #mahomes #kelce #jaycutler #pacheco #theman #taylorswift #theerastour ',
#   'comment_count': 11,
#   'id': 7330414690285276458,
#   'share_count': 2,
#   'username': 'fieldsofmemes',
#   'view_count': 213,
#   'hashtag_names': ['taylorswift',
#    'bears',
#    'theman',
#    '49ers',
#    'chiefs',
#    'jaycutler',
#    'nflfootball',
#    'nflplayoffs',
#    'pacheco',
#    'kelce',
#    'mahomes',
#    'nflmemes',
#    'smokinjay',
#    'superbowl58',
#    'theerastour']},
#  {'comment_count': 1,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift', 'erastour', 'tstheerastour'],
#   'id': 7330414689127550250,
#   'music_id': 7330414821034380078,
#   'username': 'itsjustasongoff',
#   'like_count': 58,
#   'region_code': 'us',
#   'share_count': 0,
#   'video_description': 'Taylor Swift - Cruel Summer LIVE at The Eras Tour 5-27-23 #taylorswift #tstheerastour #erastour ',
#   'view_count': 58},
#  {'share_count': 0,
#   'view_count': 64,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'needavacation',
#    'notasinger',
#    'taylornation',
#    'greenscreen',
#    'progressreport',
#    'teachersoftiktok',
#    'illicitaffairs',
#    'wowilooksoweirdhere'],
#   'id': 7330414681439440158,
#   'music_id': 7327136579629107974,
#   'region_code': 'us',
#   'comment_count': 0,
#   'like_count': 4,
#   'username': 'sherrymelin',
#   'video_description': 'Working on progress reports is going so well……really glad the custodians or any other teachers for that matter didn’t see my little after school performance lol #greenscreen #needavacation #teachersoftiktok #progressreport #taylorswift #taylornation #illicitaffairs #wowilooksoweirdhere #notasinger '},
#  {'music_id': 7294449191711197186,
#   'region_code': 'fr',
#   'video_description': 'Guess who ? #fypage #fyppppppppppppppppppppppp #sim #simsselves #simstok #sims4 #sims4build #simschallenge #sims #taylorsversion #taylorswifttok #taylorswifterastour #taylorxhairstyles #taylorswiftchallenge ',
#   'comment_count': 2,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['sims',
#    'sims4',
#    'sim',
#    'taylorswiftchallenge',
#    'simschallenge',
#    'taylorsversion',
#    'sims4build',
#    'fypage',
#    'fyppppppppppppppppppppppp',
#    'simstok',
#    'taylorswifttok',
#    'taylorxhairstyles',
#    'SimsSelves',
#    'taylorswifterastour'],
#   'like_count': 25,
#   'id': 7330414677370932513,
#   'share_count': 0,
#   'username': 'findthecelebrity',
#   'view_count': 5},
#  {'create_time': '2024-01-31',
#   'share_count': 10,
#   'username': 'swfiwf',
#   'view_count': 1347,
#   'comment_count': 55,
#   'hashtag_names': ['taylorswift', 'fyp'],
#   'id': 7330414647708781830,
#   'like_count': 220,
#   'music_id': 7286456149736557345,
#   'region_code': 'ar',
#   'video_description': '#taylorswift #fyp '},
#  {'id': 7330414643279645994,
#   'like_count': 33,
#   'share_count': 0,
#   'view_count': 17,
#   'hashtag_names': ['taylorswift',
#    'amazon',
#    'shop',
#    'deals',
#    'greenscreen',
#    'amazonfinds',
#    'amazondeals',
#    'amazongadget',
#    'amazonmusthaves',
#    'amazonfavorite',
#    'amazonpromocode',
#    'amazondealstoday'],
#   'create_time': '2024-01-31',
#   'music_id': 7330414759138822955,
#   'region_code': 'us',
#   'username': 'benstravelanddeals',
#   'video_description': 'More Amazon Promo Codes!!! #greenscreen #amazon #amazonmusthaves #amazongadget #amazonfinds #amazondeals #deals #amazonpromocode #taylorswift #amazondealstoday #amazonfavorite #shop  ',
#   'comment_count': 2},
#  {'id': 7330414637957123361,
#   'like_count': 24,
#   'music_id': 7304604721191652097,
#   'region_code': 'fr',
#   'video_description': 'You call me «\xa0i love u\xa0» 🤨#taylorswift #nevergettingbacktogether ',
#   'comment_count': 1,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift', 'nevergettingbacktogether'],
#   'share_count': 0,
#   'username': 'just_alynough',
#   'view_count': 0},
#  {'region_code': 'ar',
#   'video_description': 'hola jjj #greenscreen #fypシ #TaylorSwift #amoaminovia #theerastourtaylorswift #harrystyles #swiftie #arg ',
#   'comment_count': 15,
#   'hashtag_names': ['taylorswift',
#    'harrystyles',
#    'swiftie',
#    'arg',
#    'greenscreen',
#    'amoaminovia',
#    'fypシ',
#    'theerastourtaylorswift'],
#   'like_count': 219,
#   'music_id': 7114067549037382426,
#   'share_count': 1,
#   'username': 'jtshv',
#   'view_count': 1870,
#   'create_time': '2024-01-31',
#   'id': 7330414602355805446},
#  {'comment_count': 2,
#   'hashtag_names': ['taylorswift',
#    'superbowl',
#    'tech9ne',
#    'chiefs',
#    'arrowhead',
#    'afc',
#    'chiefskingdom',
#    'traviskelce',
#    'chiefsfootball'],
#   'id': 7330414592188747054,
#   'like_count': 27,
#   'video_description': '#chiefskingdom #afc #superbowl  #chiefsfootball #chiefs #arrowhead #taylorswift #traviskelce @Kanas City Chiefs #tech9ne ',
#   'view_count': 60,
#   'create_time': '2024-01-31',
#   'music_id': 6848387203412805633,
#   'region_code': 'us',
#   'share_count': 0,
#   'username': 'dwigrb21'},
#  {'hashtag_names': ['taylorswift',
#    'nfl',
#    'swifties',
#    'chiefs',
#    'greenscreen',
#    'kelce',
#    'traviskelce',
#    'takeupspace',
#    'hotfatguyclub'],
#   'id': 7330414569568963883,
#   'like_count': 484,
#   'video_description': '#greenscreen Why is Taylor Swift do threatening to insecure right wing men? These insecure men are threatened by the fact that a WOMAN, who is by every single measure more successful, powerful, notable, and influential than they are is enjoying their inherently masculine activity.  Because deep down somewhere they think that Taylor swift and her fans becoming fans of the game somehow feminizes THEM. #hotfatguyclub #takeupspace #taylorswift #swifties #kelce #traviskelce #chiefs #nfl ',
#   'share_count': 0,
#   'username': 'hotfatguyclub',
#   'view_count': 15,
#   'comment_count': 81,
#   'create_time': '2024-01-31',
#   'music_id': 7156826385225353217,
#   'region_code': 'us'},
#  {'view_count': 16,
#   'comment_count': 4,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'rammstein',
#    'art',
#    'blue',
#    'superbowl',
#    'nfl',
#    'taylor',
#    'hype',
#    'meme',
#    'grwm',
#    'fy',
#    'fyp',
#    'jamaljackson',
#    'hewillsaveus',
#    'foryoupage',
#    'brockpurdy'],
#   'music_id': 7200836138490136577,
#   'share_count': 0,
#   'username': 'taylor.swift.hate1',
#   'video_description': '#brockpurdy #hewillsaveus #art #grwm #meme #fy  #blue #taylor #taylorswift #rammstein #foryoupage #hype #fyp #jamaljackson #nfl #superbowl ',
#   'id': 7330414565127163169,
#   'like_count': 3,
#   'region_code': 'ch'},
#  {'username': 'defendwithred',
#   'id': 7330414560140152107,
#   'music_id': 7330414704759753514,
#   'region_code': 'us',
#   'like_count': 87,
#   'share_count': 0,
#   'video_description': 'thank you to everyone who participated 🙌🙌💊 #fy #fyp #drugabuse #drugawareness #fypシ #fentanylawareness #drugoverdose #awareness #tiktok #4u #taylorswift #popular #viral #recovery #foryou #foryoupage #opioidepidemicawareness #dryjanuary #drugprevention #opioidcrisis ',
#   'view_count': 13,
#   'comment_count': 3,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'popular',
#    'viral',
#    'tiktok',
#    'recovery',
#    'foryou',
#    '4u',
#    'fy',
#    'fyp',
#    'awareness',
#    'drugoverdose',
#    'drugabuse',
#    'drugawareness',
#    'drugprevention',
#    'dryjanuary',
#    'foryoupage',
#    'opioidcrisis',
#    'fypシ',
#    'fentanylawareness',
#    'opioidepidemicawareness']},
#  {'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'fearless',
#    'swiftie',
#    'theerastour',
#    'therrastourbrasil'],
#   'like_count': 44,
#   'music_id': 7330414575188527877,
#   'region_code': 'br',
#   'username': 'august_pvd2',
#   'video_description': 'Aaaa vey nem parece que esse momento rolou ate agora!! Come back taylor pleaseee! Precisamos de mais uma vinda pra realmente sentirmos tudooo… #therrastourbrasil #taylorswift #theerastour #fearless #swiftie @Taylor Swift @Taylor Nation ',
#   'comment_count': 1,
#   'id': 7330414540586290438,
#   'share_count': 0,
#   'view_count': 295},
#  {'hashtag_names': ['taylorswift',
#    'onedirection',
#    'style',
#    'famous',
#    'harry',
#    'louis',
#    'harrystyles',
#    'niall',
#    'liampayne',
#    'liam',
#    'louistomlinson',
#    'onedirectionedits',
#    'harrystylesedit',
#    'celebrity',
#    'boyband',
#    'larry',
#    'guess',
#    'zayne',
#    'lot',
#    'zaynemalik',
#    'niallhoranedit',
#    'louistomlinsonedits',
#    'harrystylesvideos',
#    'onedirectionfamily',
#    'zaynedits',
#    'harryshouse',
#    'onedirectionmemes',
#    'onedirectionreunion',
#    'loveontour',
#    'harrystylesupdates'],
#   'id': 7330414513214410030,
#   'music_id': 7330414635981523758,
#   'region_code': 'us',
#   'share_count': 0,
#   'comment_count': 0,
#   'create_time': '2024-01-31',
#   'like_count': 78,
#   'username': 'probably.clickbait',
#   'video_description': 'Liam?? Niall?? The full YouTube video is linked in our bio!! Go check it out💌 . . . #larry #onedirection #onedirectionedits #onedirectionmemes #onedirectionreunion #onedirectionfamily #liam #liampayne #niall #niallhoranedit #zayne #zaynedits #zaynemalik #louis #louistomlinson #louistomlinsonedits #boyband #harry #style #taylorswift #harrystyles #harrystylesedit #harryshouse #harrystylesvideos #harrystylesupdates #loveontour #lot #celebrity #famous #guess ',
#   'view_count': 10},
#  {'share_count': 0,
#   'username': 'withhomemadelove',
#   'create_time': '2024-01-31',
#   'like_count': 163,
#   'music_id': 7237332056610424833,
#   'region_code': 'us',
#   'view_count': 27,
#   'comment_count': 1,
#   'hashtag_names': ['taylorswift',
#    'football',
#    'superbowl',
#    'karma',
#    'tnt',
#    'glutenfree',
#    'sweettooth',
#    'decoratingcookies',
#    'chiefskingdom',
#    'superbowlparty',
#    'footballcookies',
#    'superbowlfood',
#    'royalicing',
#    'traviskelce',
#    'taylorsboyfriend',
#    'cookietutorial',
#    'superbowlcookies',
#    'superbowlpartyfood',
#    'karmaismyboyfriend'],
#   'id': 7330414508189437226,
#   'video_description': 'Football field cookies tutorial! As a build up to the Super Bowl, I’m sharing a few how-to videos on football related cookies… and maybe even some @Taylor Swift ones. 🫶🏼 #superbowl #cookietutorial #karma #tnt #traviskelce #taylorswift #footballcookies #football #superbowlcookies #superbowlfood #superbowlparty #superbowlpartyfood #chiefskingdom #royalicing #karmaismyboyfriend #decoratingcookies #sweettooth #glutenfree #taylorsboyfriend '},
#  {'region_code': 'us',
#   'share_count': 0,
#   'username': 'parkxrvsp',
#   'video_description': '#KAIPARKER kai + taylor is something i didnt know i needed | #kaiparker #tvd #chriswood #taylorswift #kai #siphoner #foryou #fyp #blowthisup #viral #zyxcba #parkxrvsp ',
#   'view_count': 125,
#   'comment_count': 1,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'viral',
#    'foryou',
#    'kai',
#    'tvd',
#    'fyp',
#    'chriswood',
#    'blowthisup',
#    'kaiparker',
#    'siphoner',
#    'zyxcba',
#    'parkxrvsp'],
#   'id': 7330414497531727150,
#   'like_count': 36,
#   'music_id': 7330414589152774954},
#  {'hashtag_names': ['taylorswift', 'tay', 'cchaxr'],
#   'like_count': 19,
#   'music_id': 7330414508099848966,
#   'video_description': '😻😻😻😻#taylorswift #tay #cchaxr ',
#   'view_count': 168,
#   'username': 'cchaxr',
#   'comment_count': 1,
#   'create_time': '2024-01-31',
#   'id': 7330414491005472005,
#   'region_code': 'ar',
#   'share_count': 0},
#  {'create_time': '2024-01-31',
#   'id': 7330414482377821447,
#   'music_id': 7330414790709365505,
#   'comment_count': 0,
#   'hashtag_names': ['believeinyourself',
#    'dancetrend',
#    'passportready',
#    'roamtheplanet',
#    'edutok'],
#   'region_code': 'id',
#   'share_count': 0,
#   'username': 'igit167',
#   'video_description': 'Bertani-5_HaloAmoyZee #RoamThePlanet #PassportReady #EduTok #DanceTrend #BelieveInYourself @taylorswift',
#   'view_count': 0},
#  {'comment_count': 446,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'swiftie',
#    'midnights',
#    'taylornation',
#    'taylorsversion',
#    'swifttok',
#    '1989taylorsversion',
#    'vaulttracks'],
#   'id': 7330414481035693358,
#   'like_count': 3791,
#   'music_id': 7294882110291151662,
#   'video_description': 'this is so true also i cant get this audio out if my head #taylorswift #taylornation #taylorsversion #swiftie #swifttok #midnights #1989taylorsversion #vaulttracks ',
#   'view_count': 12051,
#   'region_code': 'us',
#   'share_count': 28,
#   'username': 'sed2001'},
#  {'comment_count': 8,
#   'create_time': '2024-01-31',
#   'id': 7330414472802077994,
#   'like_count': 162,
#   'music_id': 6458078605279759117,
#   'view_count': 98,
#   'hashtag_names': ['taylorswift', 'swifties', 'election2024'],
#   'region_code': 'us',
#   'share_count': 0,
#   'username': 'bobbyzworld90',
#   'video_description': 'I mean, good luck with that #taylorswift #election2024 #swifties '},
#  {'comment_count': 3,
#   'hashtag_names': ['taylorswift',
#    'prediction',
#    'taylorsversion',
#    'reputationtaylorsversion'],
#   'share_count': 0,
#   'video_description': '#taylorswift #taylorsversion #reputationtaylorsversion #prediction ',
#   'view_count': 85,
#   'create_time': '2024-01-31',
#   'id': 7330414467680898334,
#   'like_count': 5,
#   'music_id': 6752003159637362689,
#   'region_code': 'us',
#   'username': 'totallynotshreya'},
#  {'create_time': '2024-01-31',
#   'like_count': 230,
#   'region_code': 'dm',
#   'share_count': 0,
#   'username': 'hg.lovegood',
#   'video_description': 'so much for family & friends Luke... | the tears in his eyes when he saw annabeth</3 | #annabethchase #lukecastellan #percyjackson #leahsavajeffries #charliebushnell #percyjacksonandtheolympians #pjo #foryou #fyp #viral #sadedits #harrystyles #taylorswift ',
#   'comment_count': 24,
#   'hashtag_names': ['taylorswift',
#    'harrystyles',
#    'viral',
#    'foryou',
#    'percyjackson',
#    'fyp',
#    'pjo',
#    'annabethchase',
#    'sadedits',
#    'lukecastellan',
#    'percyjacksonandtheolympians',
#    'leahsavajeffries',
#    'charliebushnell'],
#   'id': 7330414460676476166,
#   'music_id': 7330414466370013958,
#   'view_count': 106},
#  {'share_count': 0,
#   'username': 'talllly8',
#   'view_count': 173,
#   'effect_ids': ['141807271'],
#   'like_count': 44,
#   'music_id': 7107403277616023553,
#   'region_code': 'us',
#   'video_description': 'Wow, did you Know Jason Kelce was that active back in the day? #taylorswift #oldman #newtrend #dad @Jason Kelce  @Peetapumpkineata ',
#   'comment_count': 1,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift', 'dad', 'oldman', 'newtrend'],
#   'id': 7330414457367186730},
#  {'id': 7330414438312430880,
#   'music_id': 7252896191607064577,
#   'region_code': 'de',
#   'comment_count': 1,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'swifty',
#    'swifties',
#    'swiftie',
#    'foryou',
#    'performance',
#    'speaknow',
#    'fy',
#    'fyp',
#    'betterthanrevenge',
#    'speaknowtour',
#    'xyzbca'],
#   'like_count': 66,
#   'share_count': 0,
#   'username': 'tay.swift.performances',
#   'video_description': 'Better than Revenge💜 | Live at the Speak now Tour!🫶🏻 | If u wnat a specific performance write it in the comments !!💫 • #taylorswift #performance #foryou #fy #fyp #xyzbca #swiftie #swifty #swifties #speaknowtour #speaknow #betterthanrevenge ',
#   'view_count': 14},
#  {'music_id': 7223018485192919835,
#   'share_count': 0,
#   'username': 'iceland2023',
#   'video_description': '#iceland #icelandadventure #icelandic #icelandtravel #icelandtiktok #taylorswift #waterfall #icelandtrip #travel #beautifull #waterfalls ',
#   'view_count': 0,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'travel',
#    'waterfall',
#    'waterfalls',
#    'beautifull',
#    'iceland',
#    'icelandic',
#    'icelandtrip',
#    'icelandtravel',
#    'IcelandAdventure',
#    'icelandtiktok'],
#   'like_count': 1,
#   'comment_count': 0,
#   'id': 7330414425805131054,
#   'region_code': 'us'},
#  {'id': 7330414421103086855,
#   'like_count': 20,
#   'music_id': 7330414514606770945,
#   'username': 'ssotd',
#   'video_description': 'Day 188 of SSOTD \U0001fa75 #taylorswift #swifttok #swiftie #swifties #erastour #erastourtaylorswift #spinthewheel #australianswiftie #australianswifties #ssotd #swiftiessongoftheday #ssotd_tiktok ',
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'swifties',
#    'swiftie',
#    'spinthewheel',
#    'ssotd',
#    'swifttok',
#    'australianswiftie',
#    'erastourtaylorswift',
#    'erastour',
#    'australianswifties',
#    'ssotd_tiktok',
#    'swiftiessongoftheday'],
#   'region_code': 'au',
#   'share_count': 0,
#   'view_count': 430,
#   'comment_count': 0},
#  {'create_time': '2024-01-31',
#   'id': 7330414400773393694,
#   'username': 'nflmemes_tiktok',
#   'view_count': 2398,
#   'video_description': 'We know he couldn’t hang on, that’s for sure #NFL #Football #KansasCity #Chiefs #SanFrancisco #49ers #SuperBowl #LasVegas #Vegas #PatrickMahomes #TaylorSwift #TravisKelce #Swifties #BrockPurdy #FYP #NFLMemes #Memes #Airplane #Plane #Travel #Flight ',
#   'comment_count': 155,
#   'hashtag_names': ['taylorswift',
#    'football',
#    'sanfrancisco',
#    'vegas',
#    'travel',
#    'lasvegas',
#    'airplane',
#    'superbowl',
#    'nfl',
#    'plane',
#    'swifties',
#    'flight',
#    '49ers',
#    'kansascity',
#    'memes',
#    'fyp',
#    'chiefs',
#    'traviskelce',
#    'patrickmahomes',
#    'nflmemes',
#    'brockpurdy'],
#   'like_count': 2716,
#   'music_id': 7330414583062072094,
#   'region_code': 'us',
#   'share_count': 21},
#  {'id': 7330414396436499755,
#   'region_code': 'us',
#   'share_count': 0,
#   'username': 'alltoounwelll.13',
#   'video_description': 'rep first bcs one week till the eras tour starts which means hopefully a little over a week till rep tv announcement!!! #taylorswift #taylorsversion #taylornation #erastour #rep #reputation #reptv #reptaylorsversion #reputationtv #reputationtaylorsversion #fyp',
#   'view_count': 49,
#   'comment_count': 4,
#   'hashtag_names': ['taylorswift',
#    'rep',
#    'reputation',
#    'fyp',
#    'taylornation',
#    'taylorsversion',
#    'reptv',
#    'reputationtaylorsversion',
#    'reptaylorsversion',
#    'reputationtv',
#    'erastour'],
#   'music_id': 7261310163721374490,
#   'create_time': '2024-01-31',
#   'like_count': 103},
#  {'region_code': 'mx',
#   'username': 'martincito_1993',
#   'view_count': 246,
#   'comment_count': 0,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'arianagrande',
#    'nickiminaj',
#    'lol',
#    'humor',
#    'viral',
#    'pinkfriday',
#    'tiktok',
#    'foryou',
#    'parati',
#    'fyp',
#    'frases',
#    'H2LOL',
#    'martinsalinascarbajal',
#    'dianasalinascarbajal',
#    'csantysalinas',
#    'lourdessalinascarbajal',
#    'fortinosalinascarbajal',
#    'dennyasalinas'],
#   'like_count': 8,
#   'music_id': 6817179937766639617,
#   'id': 7330414382276644101,
#   'share_count': 0,
#   'video_description': '#foryou #parati #frases #h2lol #nickiminaj #arianagrande #lol #martinsalinascarbajal #viral #dianasalinascarbajal #tiktok #lourdessalinascarbajal #fyp #fortinosalinascarbajal #humor #dennyasalinas #csantysalinas #taylorswift #pinkfriday '},
#  {'hashtag_names': ['tiktok',
#    'bobo',
#    'pfy',
#    'noflop',
#    'keniaos',
#    '🏳️\u200d🌈',
#    'salgoenparati',
#    'xzyabc',
#    'tiktikponemeenparati',
#    'taylorswifttok'],
#   'id': 7330414361225235717,
#   'music_id': 7117836545108888326,
#   'share_count': 0,
#   'username': '_.ag7os_',
#   'comment_count': 4,
#   'create_time': '2024-01-31',
#   'like_count': 27,
#   'region_code': 'mx',
#   'video_description': "I didn't like the quality ##salgoenparati #tiktikponemeenparati #bobo #keniaos #pfy #xzyabc #🏳️\u200d🌈 #tiktok #noflop #taylorswifttok @TikTok @charli d’amelio ",
#   'view_count': 273},
#  {'share_count': 0,
#   'username': 'mary.go__round',
#   'hashtag_names': [],
#   'like_count': 51,
#   'music_id': 7030586717467838465,
#   'region_code': 'gb',
#   'video_description': 'I question how these people are active members of society#fyp#trishapaytas#ralphlauren#saltburn#topher#joshhutcherson#barbiemovie#taylorswift#popculture ',
#   'view_count': 22,
#   'comment_count': 1,
#   'create_time': '2024-01-31',
#   'id': 7330414355391057184},
#  {'video_description': '#taylorswift #taylor #newscelebrity #celebrity #celebrities #hollywood #news #Trending #usa #Foryou #traviskelce #game ',
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'game',
#    'celebrities',
#    'usa',
#    'taylor',
#    'hollywood',
#    'trending',
#    'celebrity',
#    'foryou',
#    'news',
#    'traviskelce',
#    'newscelebrity'],
#   'username': 'taylorfandnewa',
#   'music_id': 7211888944462596098,
#   'region_code': 'us',
#   'share_count': 0,
#   'view_count': 91,
#   'comment_count': 0,
#   'id': 7330414336613322030,
#   'like_count': 55},
#  {'hashtag_names': ['taylorswift',
#    'kanyewest',
#    'kanye',
#    '49ers',
#    'aceofspades707'],
#   'id': 7330414283756571950,
#   'region_code': 'us',
#   'comment_count': 9,
#   'like_count': 157,
#   'music_id': 7274722834260282145,
#   'share_count': 0,
#   'username': 'ace_of_spades707',
#   'video_description': '#aceofspades707 #kanye #taylorswift #kanyewest #49ers ',
#   'view_count': 20,
#   'create_time': '2024-01-31'},
#  {'region_code': 'br',
#   'comment_count': 451,
#   'like_count': 1956,
#   'id': 7330414263288270086,
#   'music_id': 7180385830475811589,
#   'share_count': 145,
#   'username': 'hellsmitch',
#   'video_description': 'é raro mas acontece muito #taylorswift #taylorsversion #humor #trending #foryoupage ',
#   'view_count': 8819,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'humor',
#    'trending',
#    'taylorsversion',
#    'foryoupage']},
#  {'music_id': 7242381184442338074,
#   'region_code': 'us',
#   'comment_count': 77,
#   'hashtag_names': ['taylorswift',
#    'swifties',
#    'taylorswiftchallenge',
#    'taylorsversion',
#    'twentysomethingsoftiktok',
#    'folklorealbum',
#    'peacetaylorswift',
#    'folklorecardigan'],
#   'id': 7330414249044479274,
#   'like_count': 1012,
#   'view_count': 271,
#   'create_time': '2024-01-31',
#   'share_count': 0,
#   'username': 'giselelizbth',
#   'video_description': 'EVERYBODY THINKS OUR LOVE IS FOR SHOW BUT I WOULD DIE FOR YOU IN SECRET!?!?!!!! #taylorswift #taylorsversion #peacetaylorswift #folklorealbum #swifties #twentysomethingsoftiktok #taylorswiftchallenge #folklorecardigan '},
#  {'username': 'jadejesser',
#   'video_description': 'Idaho Joe speaks the truth about Taylor Swift! #idahojoe #fyp #taylorswift #voteblue2024💙 #liberalsoftiktok #democrats #trumpsterfire #foryou #satire #conspiracy ',
#   'comment_count': 45,
#   'music_id': 7330414357345585950,
#   'playlist_id': 7211529422606846766,
#   'region_code': 'us',
#   'share_count': 1,
#   'view_count': 62,
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'foryou',
#    'conspiracy',
#    'fyp',
#    'satire',
#    'democrats',
#    'trumpsterfire',
#    'liberalsoftiktok',
#    'idahojoe',
#    'voteblue2024💙'],
#   'id': 7330414207193599262,
#   'like_count': 141},
#  {'hashtag_names': ['taylorswift',
#    'oc',
#    'cosplay',
#    'foryou',
#    'bipride',
#    'ai',
#    'morph',
#    'fyp',
#    'cosplayer',
#    'catgirl',
#    'queenskyecoven',
#    '🐝thebeehive🐝🐝🐝⚔️360⚔️',
#    'brokenbutbeautifulmisfits'],
#   'region_code': 'us',
#   'username': 'skyelight84',
#   'video_description': 'Whoaaa 😂#fyp #foryou #morph #taylorswift #ai #queenskyecoven #catgirl #oc #cosplay #cosplayer #bipride #brokenbutbeautifulmisfits #🐝thebeehive🐝🐝🐝⚔️360⚔️ ',
#   'create_time': '2024-01-31',
#   'id': 7330414194585554206,
#   'like_count': 57,
#   'music_id': 7252896191606835201,
#   'share_count': 0,
#   'view_count': 15,
#   'comment_count': 37},
#  {'comment_count': 0,
#   'hashtag_names': ['taylorswift',
#    'kendricklamar',
#    'relatable',
#    'badblood',
#    'ts',
#    'fyp',
#    'urdone',
#    '✨',
#    '1989',
#    'capcut',
#    '1989taylorsversion',
#    'taylorisourqueen',
#    'bejeweledtaylorswift',
#    'taylorswifterastour'],
#   'id': 7330414184561134890,
#   'share_count': 0,
#   'video_description': 'I would take like a hr on it then like 2 views.. but still grateful @Taylor Swift @Taylor Nation  #relatable #bejeweledtaylorswift #badblood #1989 #1989taylorsversion #fyp #urdone #taylorisourqueen #kendricklamar #taylorswifterastour #taylorswift #taylorswift #✨ #ts #CapCut ',
#   'view_count': 5,
#   'create_time': '2024-01-31',
#   'like_count': 77,
#   'music_id': 7067382546014980911,
#   'region_code': 'us',
#   'username': 'swifties.editz_'},
#  {'comment_count': 0,
#   'region_code': 'us',
#   'username': 'placidplanner',
#   'video_description': 'All This T&T Buzz Has Me Reminiscing About This NFL Power Couple. Planned In 6ish Months Using 💯 Of Our Recommended Vendors  Captured By Mountainaire Gathetings  #lakeplacid #adirondacks #quietluxury #tiktokbride #tiktokwedding #fyp #traviskelce #nfl #taylorswift ##mojo.video ',
#   'create_time': '2024-01-31',
#   'hashtag_names': ['taylorswift',
#    'nfl',
#    'mojo',
#    'adirondacks',
#    'fyp',
#    'lakeplacid',
#    'traviskelce',
#    'tiktokwedding',
#    'tiktokbride',
#    'quietluxury'],
#   'id': 7330414181298064683,
#   'like_count': 7,
#   'music_id': 7330414305105726254,
#   'share_count': 0,
#   'view_count': 7}]

# %%
data_df = pd.DataFrame(data)
data_df
# Out:
#    create_time                                      hashtag_names  \
# 0   2024-01-31  [taylorswift, twerk, free, dance, cute, pretty...
# 1   2024-01-31  [taylorswift, taylorswiftsongs, taylorsversion...
# 2   2024-01-31  [taylorswift, collaboration, dontletthisflop, ...
# 3   2024-01-31  [taylorswift, nicki, fyp, overwatch, irishtikt...
# 4   2024-01-31  [taylorswift, oneday, taylorswiftedit, taylors...
# ..         ...                                                ...
# 80  2024-01-31  [taylorswift, swifties, taylorswiftchallenge, ...
# 81  2024-01-31  [taylorswift, foryou, conspiracy, fyp, satire,...
# 82  2024-01-31  [taylorswift, oc, cosplay, foryou, bipride, ai...
# 83  2024-01-31  [taylorswift, kendricklamar, relatable, badblo...
# 84  2024-01-31  [taylorswift, nfl, mojo, adirondacks, fyp, lak...
#
#                      id  like_count             music_id  \
# 0   7330415306508258606         0.0  7330415422976641834
# 1   7330415285964410144        49.0  7330415331829205792
# 2   7330415271724862762        18.0  7330415390612294443
# 3   7330415265999621409       133.0  7330415315624053536
# 4   7330415255614491910        20.0  6921404355770632194
# ..                  ...         ...                  ...
# 80  7330414249044479274      1012.0  7242381184442338074
# 81  7330414207193599262       141.0  7330414357345585950
# 82  7330414194585554206        57.0  7252896191606835201
# 83  7330414184561134890        77.0  7067382546014980911
# 84  7330414181298064683         7.0  7330414305105726254
#
#                                     video_description  comment_count  \
# 0   Its code 138390143 to see her #gnb #gnbofficia...              0
# 1   the willow porfomence on top #taylorsversion #...              3
# 2   I love this edit and this girl so much @addie ...              3
# 3   #fyp #overwatch #floptok #irishtiktok #nicki #...             17
# 4   “you weren’t mine to lose” ☁️ (im so ready to ...              1
# ..                                                ...            ...
# 80  EVERYBODY THINKS OUR LOVE IS FOR SHOW BUT I WO...             77
# 81  Idaho Joe speaks the truth about Taylor Swift!...             45
# 82  Whoaaa 😂#fyp #foryou #morph #taylorswift #ai #...             37
# 83  I would take like a hr on it then like 2 views...              0
# 84  All This T&T Buzz Has Me Reminiscing About Thi...              0
#
#    region_code  share_count           username  view_count voice_to_text  \
# 0           US            0           loki3727           0           NaN
# 1           fr            0       comic_useful          28           NaN
# 2           us            0  thatswiftie131313           6           NaN
# 3           fr            0           astiryah           5           NaN
# 4           co            3        willestears         171           NaN
# ..         ...          ...                ...         ...           ...
# 80          us            0       giselelizbth         271           NaN
# 81          us            1         jadejesser          62           NaN
# 82          us            0        skyelight84          15           NaN
# 83          us            0    swifties.editz_           5           NaN
# 84          us            0      placidplanner           7           NaN
#
#    effect_ids   playlist_id
# 0         NaN           NaN
# 1         NaN           NaN
# 2         NaN           NaN
# 3         NaN           NaN
# 4         NaN           NaN
# ..        ...           ...
# 80        NaN           NaN
# 81        NaN  7.211529e+18
# 82        NaN           NaN
# 83        NaN           NaN
# 84        NaN           NaN
#
# [85 rows x 14 columns]

# %%
for i, row in data_df.iterrows():
    print(row["video_description"])
# Out:
# Its code 138390143 to see her #gnb #gnbofficial #britneyarmy #britneyisnotfree #britneygno #gnbcouple #gnboffical #gnbcollection #plane #planeedit #planecrash #planechallenge #planelovers #planeproblems planemode #fyp #toryou#ofleaks #temuleaks #temu #free #freeleaks#ishowspeed #asmrsounds #asmr #fyp #viral #speed#trendinguser511655123781 #albania #foryou #ishowspeedclipz #leaks #leak #fy #fypage #viral #typpppppppppp #trending #trendy  #trend #temu #id #surroundsound #ceilingchallenge #dancechallenge #reels #tiktok #dance #Superbowl #swifties #taylorswift #traviskelce #speed##truck" #twitter #xvideos #21savage #kaicenat #ishowspeed #yourrage#lenatheplug #typ #foryoupage #foryourpage #viral #discovery #fypp #trending #twerk #bigg #fyp #4u #blowthisup #cute #leaks #pretty hhhgf
# the willow porfomence on top #taylorsversion #taylorswifterastour #taylorswiftsongs #taylorswift #theerastour
# I love this edit and this girl so much @addie #CapCut #taylorswift #dontletthisflop #collaboration
# #fyp #overwatch #floptok #irishtiktok #nicki #floptropicaflops #taylorswift
# “you weren’t mine to lose” ☁️ (im so ready to cry for them once again in a week!!)  #taylorswift #oneday #onedaynetflix #onedayedit #onedaynetflixedit #onedaydavidnicholls #taylorswiftedit #taylorsversion
# #lover #taylorswifttok #CapCut #crochet #cursosonline #crochetaddiction #crochetbag #crochettop #crocheter
# Ken Carson is way better 🥱💀#fyp #imback #kencarson #taylorswiftsucks #imhim
# Can school just be over already🥰 #coconut #coconutgirl #coconut.girlies0 #beach #summer #summer2024 #fyp #fypシ #foryoupage #viral #viralvideo #foryou #hawaii #summervibes #wedidnotcopyanyone #summertiktok #ocean #taylorswift #fyppp
# We did it! @lululemon we love you🫶 #run #running #eveningroutine #eveningrun #coupletok #ootd #OOTD #outfit #runoutfit #runningoutfit #runner #training #workout #workingout #couplestiktok #couplesoftiktok #lululemon #gymshark #hokas #outfitideas #outfitinspo #athlesuire #athlesiurewear #comeonarunwithme #goonarunwithme #comeonarunwithus #relationship #couplegoals #fyp #viral #lookgoodfeelgood #elevatorootd #apartmentliving #apartmentlife #goals #philly #philadelphia #phillytok #phillytiktok #philadelphian #philadelphians #philadelphiaeagles #philadelphia76ers #ootdfashion #fashion #lululemonaddict #superbowl #football #sports #sporty #sportswear #chiefs #49ers #taylorswift #kansascitychiefs
# #duet with @🔥✨HausofPetty✨🔥 #twitter #x #elonmusk #billionaire #corporate #ceo #lost #shares #poorman #richman #funny #taylorswift #oops #court #epic #epicfail #bank #money #cash #assets #wealth #delicious
# #taylorswifttok #taylorswift #swiftie #joyeria #emprendedor #tendenciadejoveria #elevatulookconaccesorios #emprendiendo #ghaliagems #fyp #etiquetala #menciona #jewelry #estilo #tendencia
# #CapCut 💙 #taylorswift #taylorswifttok #swiftie #fox #foxnewsisajoke #voteblue #funny #karma #vote #2024 #f #fyp #fypシ #fypage #fu
# #TARAYUMMY|#brocksociety|i fixed my blur finally🙏| #velocity#velocityedit #fyp #foryou #foryoupage #TimeWarpScan #recreate #same #edit#taylorswift #swiftie #taylor #swift#taylorswifttickets #taylorswiftconcert#samgolbach #colbybrockedit #brock#brockscc#colby #golbach #samgolbachedit #mattsturniolo#mattstunrioloedit #chrissturniolo#chrissturnioloedit #nicksturniolo#nicksturnioloedit #thesturniolotriplets #thesturniolotripletsedit #triplets#sturniolotriplets #jakewebber#jakewebberedit#tarayummy#tarayummyedit #katrinastuart#katrinastuartedit #coreysherer#coreyshereredit#arrondoh#arrondohedit#construction#xcyba#brocksociety#cxlbyzfx
# #TikTokHolidays #houstontx #houston #vintagechristmas  #christmas #texas #nostalgia #nostalgiachristmas #memories #childhoodmemories #summer #taylorswift #britneyspears
# #evermore #swiftie #swifties #swiftietok #evermorestan #tswift #taylorswift #taylorswiftsingalong #singalong #poetry #lyricalgenius #illgobacktola #taylorsversion #erastour #erastourtaylorswift #ts #swifttok #swiftok #swiftoker #swifttoker #🌈
# #tiktokpoll #taylorswift #hereatlastofficial @Taylor Swift
# I hate this 😾 #editssxchloee #ashleybarnes #barnies #aly #alysloan #edits #ts #taylorswift #dancemoms #2 #twolovehearts #fyp #like #dontflop #took7hourstomake #july #yes #ella #chlobird #chloe #ily #viral #zyxcba
# i love the way he talks about her and their relationship 🥹 #taylorswift #swifttok #swiftie #taylorandtravis #taylorswifttraviskelce #taylorswiftnfl #taylorswiftchiefs
# Give us a break already!  #chiefs #taylorswift #butteredsausage #capcut
# 𝕀'𝕝𝕝 𝕗𝕠𝕣𝕖𝕧𝕖𝕣 𝕓𝕖 𝕝𝕠𝕧𝕖𝕤𝕥𝕣𝕦𝕔𝕜 𝕠𝕧𝕖𝕣 𝕥𝕙𝕚𝕤 𝕓𝕠𝕪😍🥰 🤍 ‘dana is from @divinepups.co - Use code 𝕔𝕠𝕡𝕡𝕖𝕣𝕝𝕒𝕟𝕖𝟙𝟝 at checkout to save😍 #lover #loverboy #valentines #puppies #puppiesoftiktok #puppylove #aussies #aussie #dogs #dogs #oklahoma #taylorswift
# WHY UMG WHY ??? #umg #taylorswift #sza
# Make a folklore bracelet with me (fun fact: betty is my fav t swift song🩷)  #taylorswift #theerastour #tstheerastour #friendshipbracelets #yoyok #taylorswift13 #taylorswifterastour #taylorswiftconcert #taylornation #taylorsversion #bracelettrading #etsy #jewelry #bracelets #bracelet #taylurking #swiftie #swifties #swiftiesforever #swiftiemerch #taylorswiftshop #midnights #redtv #reputation #swiftie #1989tv #lover #speaknowtv #taylorswift13
# Noticia de último momento!! No me imsgino una plataforma que no tenga estos audios! Ayudaaa  #music #badbunny #taylorswift #tiktok
# Day 1 of turning my coworkers into Swifties before the Super Bowl! 👀 #taylorswift #taylorsversion #taylornation #tayvis #tayvisbowl #reactingtotaylorswift #listeningtotaylorswiftfirsttime #turningintoswiftie #erastour #SuperBowl #SuperBowlLVIII #reactingtofolklore #listeningtofolklore #folklore #mytearsricochet #ariasorganization
# #superbowl2024 #taylorswift #football #trending #kelceswift #viralvideo #followback #madden2025 #biggame #49ers #chiefs #chiefsnation #tiktokfamous #viral #10000followers10days #vegas
# @Taylor Swift #TaylorSwift #FoxNews #Defamation #Consequences #StrongWoman #RepublicanLiars #TrumpRepublicanCrimeParty #VoteBlueSaveDemocracy #Swifties #FYP
# #traviskelce says he can’t go to the #grammys to support #taylorswift  #traviskelcetaylorswift
# I think ima take TAYLOR #taylorswift #fyp #xzyabc #shadowbanned #theerastour #swiftie4ever #blowthisup #tripletthreat #fypdoesntwork #viralvideo #taylorswiftedit #CapCut
# For all of of those niners fans looking to rain on Taylor Swifts parade this is the short for you! Order now to get it in time for the game! #superbowl #49ers #49ersfaithful #nfl #taylorswift #swiftie #sanfrancisco #sanfrancisco49ers #niners #goniners
# #kendrick #kendricklamar #damn#taylorswift #1989
# #duet with @Pearlmania500 #TaylorSwift
# 2024 camrea roll so far 🌶️🩵#2024 #taylorswift #febuary #january #travel #crazy #love #4lifers
# cause why yall crying ? #fyp #kcchiefs #taylorswift
# lo amo tanto, tanto<3  #harrystyles #hslot #taylorswift #hazza
# how'd I miss this!! @jack antonoff AND @FLETCHER pictured together?! 🔥💀 and all the other stuff this week hmm 🔍 KARMA BRINGS ALL MY FRIENDS TO THE SUMBIT 🌄👀 jack is starting his own record label #karmabringsallmyfriendstothesummit #dontbesuspicious #fletcher #erasofus #erasofusfletcher #leadmeonfletcher #whydontyoujustleadmeon #inthesearchofantidote #antidote #jackantanoff #thebleachers #jackantonoffandtaylorswift #taylorswift #alltoowell #redtaylorsversion  #1989TaylorsVersion #noexplanationjustreputation #reputationtaylorsversion #friendofdorothea #bettytaylorswift #lgbtq #lgbt🌈 #proud #taylorswifteastereggs #taylorswifteasteregg #taylorsversion #123lgb #newyork #newyorkcity #swifties #swiftie #swifttok #swiftok #swiftietiktok #swiftietok #swiftie4ever #taylornation #youtube #instagram #fyp  @Taylor Nation @Taylor Swift
# so much to love about this vinyl display! you can pick one up in store!@Vylümi  #criminalrecordsatl #recordstore #vinyltok #shopsmall #newvinyl #vinyldisplay #vylumi #recordcollector #taylorswiftmidnights
# love ya @mathilda 💞 | #zeesmultiix #fyp #foryoupage #fyy #edit #bestfriends #bff #top3 #titanic #suicidesquad #theflash #youngroyals #melissabenoist #benjaminwadesworth #taylorswift #abba #harrywells #marcuslopez #westallen #jackandrose #athousandboykisses #agoodgirlsguidetomurder  @Jael @marta <3 @~ Chloe ( Lana’s version ) ~ @Frieda @♡숩♡|𒈔𒉽𒈔 @Israel Echikwu @district.everdeen @Mafia_ musteata @Lily (Taylor’s version) @𝐣𝐮𝐥𝐢𝐞 @tv series 🫀🎬 @𝔍𝔬𝔫𝔞𝔱𝔥𝔞𝔫 ۵ @sav (damon’s version) @˗ˏˋ 𝖊𝖑𝖑𝖆 ´ˎ˗ @Archer.aep @Gabby🧣⸆⸉ @g ✧ @clo ౨ৎ
# 🤍#jessmariano #roryandjess #rorygilmore #deanforester #deanandrory #taylorswift
# #taylorswift 💃🏼 #traviskelce 🕺🏻 #lover #nfl #chiefs #singer #dailycuties #et #repost
# quedo horrible,  pero el punto esque la amo , ella es la que me llena el vacío en mi corazón,  mi taysita linda,  la adoro , siempre la amaré,  y la amo , mi taysita,  ni número 1 , mi mundo , TODO , la adoro 💗 #swifties #taylorswift #taylornation #antoniavuelve💔 #swifttok #fouryoupage #swiftie
# Lavander Haze-Taylor Swifts #taylorswift #capcut #tiktok #seguidores #fy #fypシ゚viral #fypシ #fypシ #amortaylorswift #brasil🇧🇷 #lavanderhazetaylorswift
# It is really a good number #13 #purdy #nfl #edit #superbowl #superbowl2024 #taylorswift #brockpurdy #fypシ #niners #espn #football #swifty #viral
# #taylornation #taylorswift
# “I’m going to Disney World” could be taken to a whole new level if Travis Kelce wins the Super Bowl MVP… I *think* it would be a little crowded that day… *if* it happened… which is not unrealistic.  #disneyworld #Super Bowl #chiefs #taylorswift #traviskelce
# #cowboylikeme #cowboylikemesupremacy #cowboylikemetaylorswift #swifttok #swiftiesforever #swiftiesunite #taylorsversion #🌈🌈 #taylorswift #underratedsongs #underratedtaylorswiftsongs #evermore #evermoretaylorswift #evermorestan #evermorealbum
# #vamostaylorswiftmipatrona❤️‍ #taylor #taylorsacareptv👹 #laseras #taylorswift #taytay🦋 #taylorteamo #parati #fyb #fyr 💕💕
# The Super Bowl we all deserve. #nflmemes #smokinjay #49ers #Chiefs #Superbowl58 #nflfootball #nflplayoffs #bears #mahomes #kelce #jaycutler #pacheco #theman #taylorswift #theerastour
# Taylor Swift - Cruel Summer LIVE at The Eras Tour 5-27-23 #taylorswift #tstheerastour #erastour
# Working on progress reports is going so well……really glad the custodians or any other teachers for that matter didn’t see my little after school performance lol #greenscreen #needavacation #teachersoftiktok #progressreport #taylorswift #taylornation #illicitaffairs #wowilooksoweirdhere #notasinger
# Guess who ? #fypage #fyppppppppppppppppppppppp #sim #simsselves #simstok #sims4 #sims4build #simschallenge #sims #taylorsversion #taylorswifttok #taylorswifterastour #taylorxhairstyles #taylorswiftchallenge
# #taylorswift #fyp
# More Amazon Promo Codes!!! #greenscreen #amazon #amazonmusthaves #amazongadget #amazonfinds #amazondeals #deals #amazonpromocode #taylorswift #amazondealstoday #amazonfavorite #shop
# You call me « i love u » 🤨#taylorswift #nevergettingbacktogether
# hola jjj #greenscreen #fypシ #TaylorSwift #amoaminovia #theerastourtaylorswift #harrystyles #swiftie #arg
# #chiefskingdom #afc #superbowl  #chiefsfootball #chiefs #arrowhead #taylorswift #traviskelce @Kanas City Chiefs #tech9ne
# #greenscreen Why is Taylor Swift do threatening to insecure right wing men? These insecure men are threatened by the fact that a WOMAN, who is by every single measure more successful, powerful, notable, and influential than they are is enjoying their inherently masculine activity.  Because deep down somewhere they think that Taylor swift and her fans becoming fans of the game somehow feminizes THEM. #hotfatguyclub #takeupspace #taylorswift #swifties #kelce #traviskelce #chiefs #nfl
# #brockpurdy #hewillsaveus #art #grwm #meme #fy  #blue #taylor #taylorswift #rammstein #foryoupage #hype #fyp #jamaljackson #nfl #superbowl
# thank you to everyone who participated 🙌🙌💊 #fy #fyp #drugabuse #drugawareness #fypシ #fentanylawareness #drugoverdose #awareness #tiktok #4u #taylorswift #popular #viral #recovery #foryou #foryoupage #opioidepidemicawareness #dryjanuary #drugprevention #opioidcrisis
# Aaaa vey nem parece que esse momento rolou ate agora!! Come back taylor pleaseee! Precisamos de mais uma vinda pra realmente sentirmos tudooo… #therrastourbrasil #taylorswift #theerastour #fearless #swiftie @Taylor Swift @Taylor Nation
# Liam?? Niall?? The full YouTube video is linked in our bio!! Go check it out💌 . . . #larry #onedirection #onedirectionedits #onedirectionmemes #onedirectionreunion #onedirectionfamily #liam #liampayne #niall #niallhoranedit #zayne #zaynedits #zaynemalik #louis #louistomlinson #louistomlinsonedits #boyband #harry #style #taylorswift #harrystyles #harrystylesedit #harryshouse #harrystylesvideos #harrystylesupdates #loveontour #lot #celebrity #famous #guess
# Football field cookies tutorial! As a build up to the Super Bowl, I’m sharing a few how-to videos on football related cookies… and maybe even some @Taylor Swift ones. 🫶🏼 #superbowl #cookietutorial #karma #tnt #traviskelce #taylorswift #footballcookies #football #superbowlcookies #superbowlfood #superbowlparty #superbowlpartyfood #chiefskingdom #royalicing #karmaismyboyfriend #decoratingcookies #sweettooth #glutenfree #taylorsboyfriend
# #KAIPARKER kai + taylor is something i didnt know i needed | #kaiparker #tvd #chriswood #taylorswift #kai #siphoner #foryou #fyp #blowthisup #viral #zyxcba #parkxrvsp
# 😻😻😻😻#taylorswift #tay #cchaxr
# Bertani-5_HaloAmoyZee #RoamThePlanet #PassportReady #EduTok #DanceTrend #BelieveInYourself @taylorswift
# this is so true also i cant get this audio out if my head #taylorswift #taylornation #taylorsversion #swiftie #swifttok #midnights #1989taylorsversion #vaulttracks
# I mean, good luck with that #taylorswift #election2024 #swifties
# #taylorswift #taylorsversion #reputationtaylorsversion #prediction
# so much for family & friends Luke... | the tears in his eyes when he saw annabeth</3 | #annabethchase #lukecastellan #percyjackson #leahsavajeffries #charliebushnell #percyjacksonandtheolympians #pjo #foryou #fyp #viral #sadedits #harrystyles #taylorswift
# Wow, did you Know Jason Kelce was that active back in the day? #taylorswift #oldman #newtrend #dad @Jason Kelce  @Peetapumpkineata
# Better than Revenge💜 | Live at the Speak now Tour!🫶🏻 | If u wnat a specific performance write it in the comments !!💫 • #taylorswift #performance #foryou #fy #fyp #xyzbca #swiftie #swifty #swifties #speaknowtour #speaknow #betterthanrevenge
# #iceland #icelandadventure #icelandic #icelandtravel #icelandtiktok #taylorswift #waterfall #icelandtrip #travel #beautifull #waterfalls
# Day 188 of SSOTD 🩵 #taylorswift #swifttok #swiftie #swifties #erastour #erastourtaylorswift #spinthewheel #australianswiftie #australianswifties #ssotd #swiftiessongoftheday #ssotd_tiktok
# We know he couldn’t hang on, that’s for sure #NFL #Football #KansasCity #Chiefs #SanFrancisco #49ers #SuperBowl #LasVegas #Vegas #PatrickMahomes #TaylorSwift #TravisKelce #Swifties #BrockPurdy #FYP #NFLMemes #Memes #Airplane #Plane #Travel #Flight
# rep first bcs one week till the eras tour starts which means hopefully a little over a week till rep tv announcement!!! #taylorswift #taylorsversion #taylornation #erastour #rep #reputation #reptv #reptaylorsversion #reputationtv #reputationtaylorsversion #fyp
# #foryou #parati #frases #h2lol #nickiminaj #arianagrande #lol #martinsalinascarbajal #viral #dianasalinascarbajal #tiktok #lourdessalinascarbajal #fyp #fortinosalinascarbajal #humor #dennyasalinas #csantysalinas #taylorswift #pinkfriday
# I didn't like the quality ##salgoenparati #tiktikponemeenparati #bobo #keniaos #pfy #xzyabc #🏳️‍🌈 #tiktok #noflop #taylorswifttok @TikTok @charli d’amelio
# I question how these people are active members of society#fyp#trishapaytas#ralphlauren#saltburn#topher#joshhutcherson#barbiemovie#taylorswift#popculture
# #taylorswift #taylor #newscelebrity #celebrity #celebrities #hollywood #news #Trending #usa #Foryou #traviskelce #game
# #aceofspades707 #kanye #taylorswift #kanyewest #49ers
# é raro mas acontece muito #taylorswift #taylorsversion #humor #trending #foryoupage
# EVERYBODY THINKS OUR LOVE IS FOR SHOW BUT I WOULD DIE FOR YOU IN SECRET!?!?!!!! #taylorswift #taylorsversion #peacetaylorswift #folklorealbum #swifties #twentysomethingsoftiktok #taylorswiftchallenge #folklorecardigan
# Idaho Joe speaks the truth about Taylor Swift! #idahojoe #fyp #taylorswift #voteblue2024💙 #liberalsoftiktok #democrats #trumpsterfire #foryou #satire #conspiracy
# Whoaaa 😂#fyp #foryou #morph #taylorswift #ai #queenskyecoven #catgirl #oc #cosplay #cosplayer #bipride #brokenbutbeautifulmisfits #🐝thebeehive🐝🐝🐝⚔️360⚔️
# I would take like a hr on it then like 2 views.. but still grateful @Taylor Swift @Taylor Nation  #relatable #bejeweledtaylorswift #badblood #1989 #1989taylorsversion #fyp #urdone #taylorisourqueen #kendricklamar #taylorswifterastour #taylorswift #taylorswift #✨ #ts #CapCut
# All This T&T Buzz Has Me Reminiscing About This NFL Power Couple. Planned In 6ish Months Using 💯 Of Our Recommended Vendors  Captured By Mountainaire Gathetings  #lakeplacid #adirondacks #quietluxury #tiktokbride #tiktokwedding #fyp #traviskelce #nfl #taylorswift ##mojo.video
